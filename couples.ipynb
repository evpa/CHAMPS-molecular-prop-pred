# %%
import pandas as pd
import numpy as np

# %%
test = pd.read_csv('test.csv')

# %%
bayes = pd.read_csv('lgb_bayes_10k.csv')

# %%
dist = pd.read_csv('distance.csv')

# %%
median = pd.read_csv('stack_median.csv')

# %%
median.loc[test['type'] == '1JHN', 'scalar_coupling_constant'] = bayes.loc[test['type'] == '1JHN', 'scalar_coupling_constant']

# %%
median.loc[test['type'] == '2JHN', 'scalar_coupling_constant'] = bayes.loc[test['type'] == '2JHN', 'scalar_coupling_constant']

# %%
median.to_csv('median_bayes.csv', index=False)

# %%
bayes
# Out:
#               id  scalar_coupling_constant
# 0        4658147                 18.679459
# 1        4658148                162.162933
# 2        4658149                 10.099482
# 3        4658150                162.162933
# 4        4658151                 18.679459
# 5        4658152                 92.420975
# 6        4658153                  2.821239
# 7        4658154                 -7.545513
# 8        4658155                 -9.600138
# 9        4658156                 92.414619
# 10       4658157                  2.846341
# 11       4658158                 -9.607889
# 12       4658159                 83.814987
# 13       4658160                 10.966368
# 14       4658161                  2.821239
# 15       4658162                 92.420975
# 16       4658163                 -7.543633
# 17       4658164                 -9.600138
# 18       4658165                  2.846341
# 19       4658166                 92.416908
# 20       4658167                 -9.607889
# ...

# %%
dist
# Out:
#               id  scalar_coupling_constant
# 0        4658147                 22.673035
# 1        4658148                146.205200
# 2        4658149                  9.503328
# 3        4658150                146.205200
# 4        4658151                 22.673035
# 5        4658152                 91.626915
# 6        4658153                  2.746282
# 7        4658154                 -7.511728
# 8        4658155                 -9.589906
# 9        4658156                 91.629890
# 10       4658157                  2.764879
# 11       4658158                 -9.591513
# 12       4658159                 83.368958
# 13       4658160                 11.033603
# 14       4658161                  2.746282
# 15       4658162                 91.626915
# 16       4658163                 -7.512406
# 17       4658164                 -9.589906
# 18       4658165                  2.764879
# 19       4658166                 91.631653
# 20       4658167                 -9.591513
# ...

# %%
dist.to_csv('1JHN_2JHN_3JHN.csv', index=False)

# %%
dist
# Out:
#               id  scalar_coupling_constant
# 0        4658147                 22.673035
# 1        4658148                146.205200
# 2        4658149                  9.503328
# 3        4658150                146.205200
# 4        4658151                 22.673035
# 5        4658152                 91.626915
# 6        4658153                  2.746282
# 7        4658154                 -7.511728
# 8        4658155                 -9.589906
# 9        4658156                 91.629890
# 10       4658157                  2.764879
# 11       4658158                 -9.591513
# 12       4658159                 83.368958
# 13       4658160                 11.033603
# 14       4658161                  2.746282
# 15       4658162                 91.626915
# 16       4658163                 -7.512406
# 17       4658164                 -9.589906
# 18       4658165                  2.764879
# 19       4658166                 91.631653
# 20       4658167                 -9.591513
# ...

# %%
test
# Out:
#               id     molecule_name  atom_index_0  atom_index_1  type
# 0        4658147  dsgdb9nsd_000004             2             0  2JHC
# 1        4658148  dsgdb9nsd_000004             2             1  1JHC
# 2        4658149  dsgdb9nsd_000004             2             3  3JHH
# 3        4658150  dsgdb9nsd_000004             3             0  1JHC
# 4        4658151  dsgdb9nsd_000004             3             1  2JHC
# 5        4658152  dsgdb9nsd_000015             3             0  1JHC
# 6        4658153  dsgdb9nsd_000015             3             2  3JHC
# 7        4658154  dsgdb9nsd_000015             3             4  2JHH
# 8        4658155  dsgdb9nsd_000015             3             5  2JHH
# 9        4658156  dsgdb9nsd_000015             4             0  1JHC
# 10       4658157  dsgdb9nsd_000015             4             2  3JHC
# 11       4658158  dsgdb9nsd_000015             4             5  2JHH
# 12       4658159  dsgdb9nsd_000015             5             0  1JHC
# ...
