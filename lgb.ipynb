# %%
# %matplotlib inline

import pandas as pd
import numpy as np

import math
import gc
import copy

from sklearn.model_selection import KFold, train_test_split
from sklearn.metrics import mean_absolute_error

import matplotlib.pyplot as plt
import seaborn as sns

from lightgbm import LGBMRegressor

# %%
ATOMIC_NUMBERS = {
    'H': 1,
    'C': 6,
    'N': 7,
    'O': 8,
    'F': 9
}

# %%
# pd.set_option('display.max_colwidth', -1)
# pd.set_option('display.max_rows', 120)
# pd.set_option('display.max_columns', 120)

# %%
# train_dtypes = {
#     'molecule_name': 'category',
#     'atom_index_0': 'int8',
#     'atom_index_1': 'int8',
#     'type': 'category',
#     'scalar_coupling_constant': 'float32'
# }
train_csv = pd.read_csv('train.csv', index_col='id')
train_csv['molecule_index'] = train_csv.molecule_name.str.replace('dsgdb9nsd_', '').astype('int32')
train_csv = train_csv[['molecule_index', 'atom_index_0', 'atom_index_1', 'type', 'scalar_coupling_constant']]
# Out:
# C:\Users\Maynard\Anaconda3\lib\site-packages\numpy\lib\arraysetops.py:569: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)

# %%
train_csv.head()
# Out:
#     molecule_index  atom_index_0  atom_index_1  type  scalar_coupling_constant
# id
# 0                1             1             0  1JHC                   84.8076
# 1                1             1             2  2JHH                  -11.2570
# 2                1             1             3  2JHH                  -11.2548
# 3                1             1             4  2JHH                  -11.2543
# 4                1             2             0  1JHC                   84.8074

# %%
print('Shape: ', train_csv.shape)
print('Total: ', train_csv.memory_usage().sum())
train_csv.memory_usage()
# Out:
# Shape:  (4658147, 5)
# Total:  204958468
# Index                       37265176
# molecule_index              18632588
# atom_index_0                37265176
# atom_index_1                37265176
# type                        37265176
# scalar_coupling_constant    37265176
# dtype: int64

# %%
submission_csv = pd.read_csv('sample_submission.csv', index_col='id')

# %%
test_csv = pd.read_csv('test.csv', index_col='id')
test_csv['molecule_index'] = test_csv['molecule_name'].str.replace('dsgdb9nsd_', '').astype('int32')
test_csv = test_csv[['molecule_index', 'atom_index_0', 'atom_index_1', 'type']]

# %%
test_csv.head()
# Out:
#          molecule_index  atom_index_0  atom_index_1  type
# id
# 4658147               4             2             0  2JHC
# 4658148               4             2             1  1JHC
# 4658149               4             2             3  3JHH
# 4658150               4             3             0  1JHC
# 4658151               4             3             1  2JHC

# %%
# structures_dtypes = {
#     'molecule_name': 'category',
#     'atom_index': 'int8',
#     'atom': 'category',
#     'x': 'float32',
#     'y': 'float32',
#     'z': 'float32'
# }
structures_csv = pd.read_csv('structures.csv')
structures_csv['molecule_index'] = structures_csv.molecule_name.str.replace('dsgdb9nsd_', '').astype('int32')
structures_csv = structures_csv[['molecule_index', 'atom_index', 'atom', 'x', 'y', 'z']]

# %%
structures_csv['atom'] = structures_csv['atom'].replace(ATOMIC_NUMBERS).astype('int8')
structures_csv.head(10)
# Out:
#    molecule_index  atom_index  atom         x         y         z
# 0               1           0     6 -0.012698  1.085804  0.008001
# 1               1           1     1  0.002150 -0.006031  0.001976
# 2               1           2     1  1.011731  1.463751  0.000277
# 3               1           3     1 -0.540815  1.447527 -0.876644
# 4               1           4     1 -0.523814  1.437933  0.906397
# 5               2           0     7 -0.040426  1.024108  0.062564
# 6               2           1     1  0.017257  0.012545 -0.027377
# 7               2           2     1  0.915789  1.358745 -0.028758
# 8               2           3     1 -0.520278  1.343532 -0.775543
# 9               3           0     8 -0.034360  0.977540  0.007602

# %%
print('Shape: ', structures_csv.shape)
print('Total: ', structures_csv.memory_usage().sum())
structures_csv.memory_usage()
# Out:
# Shape:  (2358657, 6)
# Total:  87270389
# Index                   80
# molecule_index     9434628
# atom_index        18869256
# atom               2358657
# x                 18869256
# y                 18869256
# z                 18869256
# dtype: int64

# %%
def build_type_dataframes(base, structures, coupling_type):
    base = base[base['type'] == coupling_type].drop('type', axis=1).copy()
    base = base.reset_index()
    base['id'] = base['id'].astype('int32')
    structures = structures[structures['molecule_index'].isin(base['molecule_index'])]
    return base, structures

# %%
def add_coordinates(base, structures, index):
    df = pd.merge(base, structures, how='inner',
                  left_on=['molecule_index', f'atom_index_{index}'],
                  right_on=['molecule_index', 'atom_index']).drop(['atom_index'], axis=1)
    df = df.rename(columns={
        'atom': f'atom_{index}',
        'x': f'x_{index}',
        'y': f'y_{index}',
        'z': f'z_{index}'
    })
    return df

# %%
def add_atoms(base, atoms):
    df = pd.merge(base, atoms, how='inner',
                  on=['molecule_index', 'atom_index_0', 'atom_index_1'])
    return df

# %%
def merge_all_atoms(base, structures):
    df = pd.merge(base, structures, how='left',
                  left_on=['molecule_index'],
                  right_on=['molecule_index'])
    df = df[(df.atom_index_0 != df.atom_index) & (df.atom_index_1 != df.atom_index)]
    return df

# %%
def add_center(df):
    df['x_c'] = ((df['x_1'] + df['x_0']) * np.float32(0.5))
    df['y_c'] = ((df['y_1'] + df['y_0']) * np.float32(0.5))
    df['z_c'] = ((df['z_1'] + df['z_0']) * np.float32(0.5))

def add_distance_to_center(df):
    df['d_c'] = ((
        (df['x_c'] - df['x'])**np.float32(2) +
        (df['y_c'] - df['y'])**np.float32(2) + 
        (df['z_c'] - df['z'])**np.float32(2)
    )**np.float32(0.5))

def add_distance_between(df, suffix1, suffix2):
    df[f'd_{suffix1}_{suffix2}'] = ((
        (df[f'x_{suffix1}'] - df[f'x_{suffix2}'])**np.float32(2) +
        (df[f'y_{suffix1}'] - df[f'y_{suffix2}'])**np.float32(2) + 
        (df[f'z_{suffix1}'] - df[f'z_{suffix2}'])**np.float32(2)
    )**np.float32(0.5))

# %%
def add_distances(df):
    n_atoms = 1 + max([int(c.split('_')[1]) for c in df.columns if c.startswith('x_')])
    
    for i in range(1, n_atoms):
        for vi in range(min(4, i)):
            add_distance_between(df, i, vi)

# %%
def add_n_atoms(base, structures):
    dfs = structures['molecule_index'].value_counts().rename('n_atoms').to_frame()
    return pd.merge(base, dfs, left_on='molecule_index', right_index=True)

# %%
def build_couple_dataframe(some_csv, structures_csv, coupling_type, n_atoms=10):
    base, structures = build_type_dataframes(some_csv, structures_csv, coupling_type)
    base = add_coordinates(base, structures, 0)
    base = add_coordinates(base, structures, 1)
    
    base = base.drop(['atom_0', 'atom_1'], axis=1)
    atoms = base.drop('id', axis=1).copy()
    if 'scalar_coupling_constant' in some_csv:
        atoms = atoms.drop(['scalar_coupling_constant'], axis=1)
        
    add_center(atoms)
    atoms = atoms.drop(['x_0', 'y_0', 'z_0', 'x_1', 'y_1', 'z_1'], axis=1)

    atoms = merge_all_atoms(atoms, structures)
    
    add_distance_to_center(atoms)
    
    atoms = atoms.drop(['x_c', 'y_c', 'z_c', 'atom_index'], axis=1)
    atoms.sort_values(['molecule_index', 'atom_index_0', 'atom_index_1', 'd_c'], inplace=True)
    atom_groups = atoms.groupby(['molecule_index', 'atom_index_0', 'atom_index_1'])
    atoms['num'] = atom_groups.cumcount() + 2
    atoms = atoms.drop(['d_c'], axis=1)
    atoms = atoms[atoms['num'] < n_atoms]

    atoms = atoms.set_index(['molecule_index', 'atom_index_0', 'atom_index_1', 'num']).unstack()
    atoms.columns = [f'{col[0]}_{col[1]}' for col in atoms.columns]
    atoms = atoms.reset_index()
    
    # downcast back to int8
    for col in atoms.columns:
        if col.startswith('atom_'):
            atoms[col] = atoms[col].fillna(0).astype('int8')
            
    atoms['molecule_index'] = atoms['molecule_index'].astype('int32')
    
    full = add_atoms(base, atoms)
    add_distances(full)
    
    full.sort_values('id', inplace=True)
    
    return full

# %%
def take_n_atoms(df, n_atoms, four_start=4):
    labels = []
    for i in range(2, n_atoms):
        label = f'atom_{i}'
        labels.append(label)

    for i in range(n_atoms):
        num = min(i, 4) if i < four_start else 4
        for j in range(num):
            labels.append(f'd_{i}_{j}')
    if 'scalar_coupling_constant' in df:
        labels.append('scalar_coupling_constant')
    return df[labels]

# %%
# %%time
full = build_couple_dataframe(train_csv, structures_csv, '1JHN', n_atoms=10)
print(full.shape)
# Out:
# (43363, 73)
# Wall time: 3.66 s

# %%
full.columns
# Out:
# Index(['id', 'molecule_index', 'atom_index_0', 'atom_index_1',
#        'scalar_coupling_constant', 'x_0', 'y_0', 'z_0', 'x_1', 'y_1', 'z_1',
#        'atom_2', 'atom_3', 'atom_4', 'atom_5', 'atom_6', 'atom_7', 'atom_8',
#        'atom_9', 'x_2', 'x_3', 'x_4', 'x_5', 'x_6', 'x_7', 'x_8', 'x_9', 'y_2',
#        'y_3', 'y_4', 'y_5', 'y_6', 'y_7', 'y_8', 'y_9', 'z_2', 'z_3', 'z_4',
#        'z_5', 'z_6', 'z_7', 'z_8', 'z_9', 'd_1_0', 'd_2_0', 'd_2_1', 'd_3_0',
#        'd_3_1', 'd_3_2', 'd_4_0', 'd_4_1', 'd_4_2', 'd_4_3', 'd_5_0', 'd_5_1',
#        'd_5_2', 'd_5_3', 'd_6_0', 'd_6_1', 'd_6_2', 'd_6_3', 'd_7_0', 'd_7_1',
#        'd_7_2', 'd_7_3', 'd_8_0', 'd_8_1', 'd_8_2', 'd_8_3', 'd_9_0', 'd_9_1',
#        'd_9_2', 'd_9_3'],
#       dtype='object')

# %%
df = take_n_atoms(full, 7)
# LightGBM performs better with 0-s then with NaN-s
df = df.fillna(0)
df.columns
# Out:
# Index(['atom_2', 'atom_3', 'atom_4', 'atom_5', 'atom_6', 'd_1_0', 'd_2_0',
#        'd_2_1', 'd_3_0', 'd_3_1', 'd_3_2', 'd_4_0', 'd_4_1', 'd_4_2', 'd_4_3',
#        'd_5_0', 'd_5_1', 'd_5_2', 'd_5_3', 'd_6_0', 'd_6_1', 'd_6_2', 'd_6_3',
#        'scalar_coupling_constant'],
#       dtype='object')

# %%
X_data = df.drop(['scalar_coupling_constant'], axis=1).values.astype('float32')
y_data = df['scalar_coupling_constant'].values.astype('float32')

X_train, X_val, y_train, y_val = train_test_split(X_data, y_data, test_size=0.2, random_state=128)
X_train.shape, X_val.shape, y_train.shape, y_val.shape
# Out:
# ((34690, 23), (8673, 23), (34690,), (8673,))

# %%
LGB_PARAMS = {
    'objective': 'regression',
    'metric': 'mae',
    'verbosity': -1,
    'boosting_type': 'gbdt',
    'learning_rate': 0.0663,
    'num_leaves': 52,
    'min_child_samples': 126,
    'max_depth': -1,
    'bagging_fraction': 0.4649,
    'feature_fraction' : 0.7281,
    'reg_alpha': 0.6075,
    'reg_lambda': 0.1705,
}

# %%
def build_x_y_data(some_csv, coupling_type, n_atoms):
    full = build_couple_dataframe(some_csv, structures_csv, coupling_type, n_atoms=n_atoms)
    
    df = take_n_atoms(full, n_atoms)
    df = df.fillna(0)
    print(df.columns)
    
    if 'scalar_coupling_constant' in df:
        X_data = df.drop(['scalar_coupling_constant'], axis=1).values.astype('float32')
        y_data = df['scalar_coupling_constant'].values.astype('float32')
    else:
        X_data = df.values.astype('float32')
        y_data = None
    
    return X_data, y_data

# %%
def train_and_predict_for_one_coupling_type(coupling_type, submission, n_atoms, n_folds=5, n_splits=5, random_state=128):
    print(f'*** Training Model for {coupling_type} ***')
    
    X_data, y_data = build_x_y_data(train_csv, coupling_type, n_atoms)
    X_test, _ = build_x_y_data(test_csv, coupling_type, n_atoms)
    y_pred = np.zeros(X_test.shape[0], dtype='float32')

    cv_score = 0
    
    if n_folds > n_splits:
        n_splits = n_folds
    
    kfold = KFold(n_splits=n_splits, shuffle=True, random_state=random_state)

    for fold, (train_index, val_index) in enumerate(kfold.split(X_data, y_data)):
        if fold >= n_folds:
            break

        X_train, X_val = X_data[train_index], X_data[val_index]
        y_train, y_val = y_data[train_index], y_data[val_index]

        model = LGBMRegressor(**LGB_PARAMS, n_estimators=10000, n_jobs = -1)
        model.fit(X_train, y_train, 
            eval_set=[(X_train, y_train), (X_val, y_val)], eval_metric='mae',
            verbose=1000, early_stopping_rounds=100)

        y_val_pred = model.predict(X_val)
        val_score = np.log(mean_absolute_error(y_val, y_val_pred))
        print(f'{coupling_type} Fold {fold}, logMAE: {val_score}')
        
        cv_score += val_score / n_folds
        y_pred += model.predict(X_test) / n_folds
        
        
    submission.loc[test_csv['type'] == coupling_type, 'scalar_coupling_constant'] = y_pred
    return cv_score

# %%
# %%time

model_params = {
    '1JHN': 7,
    '1JHC': 10,
    '2JHH': 9,
    '2JHN': 9,
    '2JHC': 9,
    '3JHH': 9,
    '3JHC': 10,
    '3JHN': 10
}
N_FOLDS = 5
submission = submission_csv.copy()

cv_scores = {}
for coupling_type in model_params.keys():
    cv_score = train_and_predict_for_one_coupling_type(
        coupling_type, submission, n_atoms=model_params[coupling_type], n_folds=N_FOLDS)
    cv_scores[coupling_type] = cv_score
# Out:
# *** Training Model for 1JHN ***
# Index(['atom_2', 'atom_3', 'atom_4', 'atom_5', 'atom_6', 'd_1_0', 'd_2_0',
#        'd_2_1', 'd_3_0', 'd_3_1', 'd_3_2', 'd_4_0', 'd_4_1', 'd_4_2', 'd_4_3',
#        'd_5_0', 'd_5_1', 'd_5_2', 'd_5_3', 'd_6_0', 'd_6_1', 'd_6_2', 'd_6_3',
#        'scalar_coupling_constant'],
#       dtype='object')
# Index(['atom_2', 'atom_3', 'atom_4', 'atom_5', 'atom_6', 'd_1_0', 'd_2_0',
#        'd_2_1', 'd_3_0', 'd_3_1', 'd_3_2', 'd_4_0', 'd_4_1', 'd_4_2', 'd_4_3',
#        'd_5_0', 'd_5_1', 'd_5_2', 'd_5_3', 'd_6_0', 'd_6_1', 'd_6_2', 'd_6_3'],
#       dtype='object')
# Training until validation scores don't improve for 100 rounds.
# [1000]	training's l1: 0.274537	valid_1's l1: 0.3981
# [2000]	training's l1: 0.203166	valid_1's l1: 0.366153
# [3000]	training's l1: 0.164294	valid_1's l1: 0.352873
# [4000]	training's l1: 0.138197	valid_1's l1: 0.345547
# [5000]	training's l1: 0.119315	valid_1's l1: 0.341057
# [6000]	training's l1: 0.10488	valid_1's l1: 0.338168
# [7000]	training's l1: 0.093461	valid_1's l1: 0.336195
# [8000]	training's l1: 0.0842785	valid_1's l1: 0.334641
# [9000]	training's l1: 0.0768098	valid_1's l1: 0.333545
# [10000]	training's l1: 0.0705132	valid_1's l1: 0.332619
# Did not meet early stopping. Best iteration is:
# [10000]	training's l1: 0.0705132	valid_1's l1: 0.332619
# 1JHN Fold 0, logMAE: -1.1007589889153766
# Training until validation scores don't improve for 100 rounds.
# [1000]	training's l1: 0.27113	valid_1's l1: 0.39926
# [2000]	training's l1: 0.19988	valid_1's l1: 0.367578
# [3000]	training's l1: 0.161326	valid_1's l1: 0.354599
# [4000]	training's l1: 0.135729	valid_1's l1: 0.347343
# [5000]	training's l1: 0.116895	valid_1's l1: 0.342771
# [6000]	training's l1: 0.102802	valid_1's l1: 0.339796
# [7000]	training's l1: 0.0916845	valid_1's l1: 0.337519
# [8000]	training's l1: 0.0826993	valid_1's l1: 0.336008
# [9000]	training's l1: 0.0753195	valid_1's l1: 0.334806
# [10000]	training's l1: 0.0692066	valid_1's l1: 0.333844
# Did not meet early stopping. Best iteration is:
# [10000]	training's l1: 0.0692066	valid_1's l1: 0.333844
# 1JHN Fold 1, logMAE: -1.0970800773034648
# Training until validation scores don't improve for 100 rounds.
# [1000]	training's l1: 0.274878	valid_1's l1: 0.402043
# [2000]	training's l1: 0.203273	valid_1's l1: 0.370417
# [3000]	training's l1: 0.164066	valid_1's l1: 0.356348
# [4000]	training's l1: 0.13825	valid_1's l1: 0.348009
# [5000]	training's l1: 0.119058	valid_1's l1: 0.343021
# [6000]	training's l1: 0.104544	valid_1's l1: 0.339631
# [7000]	training's l1: 0.0931382	valid_1's l1: 0.337137
# [8000]	training's l1: 0.0839794	valid_1's l1: 0.335358
# [9000]	training's l1: 0.0764363	valid_1's l1: 0.334088
# [10000]	training's l1: 0.0702168	valid_1's l1: 0.333056
# Did not meet early stopping. Best iteration is:
# [10000]	training's l1: 0.0702168	valid_1's l1: 0.333056
# 1JHN Fold 2, logMAE: -1.099443499308333
# Training until validation scores don't improve for 100 rounds.
# [1000]	training's l1: 0.274494	valid_1's l1: 0.392345
# [2000]	training's l1: 0.203508	valid_1's l1: 0.361234
# [3000]	training's l1: 0.164082	valid_1's l1: 0.346898
# [4000]	training's l1: 0.138071	valid_1's l1: 0.338733
# [5000]	training's l1: 0.118962	valid_1's l1: 0.333792
# [6000]	training's l1: 0.104484	valid_1's l1: 0.330315
# [7000]	training's l1: 0.0930295	valid_1's l1: 0.327774
# [8000]	training's l1: 0.0838918	valid_1's l1: 0.326175
# [9000]	training's l1: 0.0764264	valid_1's l1: 0.324709
# [10000]	training's l1: 0.0701682	valid_1's l1: 0.323593
# Did not meet early stopping. Best iteration is:
# [10000]	training's l1: 0.0701682	valid_1's l1: 0.323593
# 1JHN Fold 3, logMAE: -1.1282680105043257
# Training until validation scores don't improve for 100 rounds.
# [1000]	training's l1: 0.275383	valid_1's l1: 0.397713
# [2000]	training's l1: 0.202188	valid_1's l1: 0.365673
# [3000]	training's l1: 0.163387	valid_1's l1: 0.353143
# [4000]	training's l1: 0.137644	valid_1's l1: 0.346534
# [5000]	training's l1: 0.118766	valid_1's l1: 0.342173
# [6000]	training's l1: 0.10426	valid_1's l1: 0.339126
# [7000]	training's l1: 0.0928483	valid_1's l1: 0.337073
# [8000]	training's l1: 0.0837432	valid_1's l1: 0.33543
# [9000]	training's l1: 0.0762811	valid_1's l1: 0.334227
# [10000]	training's l1: 0.0700137	valid_1's l1: 0.333391
# Did not meet early stopping. Best iteration is:
# [10000]	training's l1: 0.0700137	valid_1's l1: 0.333391
# 1JHN Fold 4, logMAE: -1.0984390907248551
# *** Training Model for 1JHC ***
# Index(['atom_2', 'atom_3', 'atom_4', 'atom_5', 'atom_6', 'atom_7', 'atom_8',
#        'atom_9', 'd_1_0', 'd_2_0', 'd_2_1', 'd_3_0', 'd_3_1', 'd_3_2', 'd_4_0',
#        'd_4_1', 'd_4_2', 'd_4_3', 'd_5_0', 'd_5_1', 'd_5_2', 'd_5_3', 'd_6_0',
#        'd_6_1', 'd_6_2', 'd_6_3', 'd_7_0', 'd_7_1', 'd_7_2', 'd_7_3', 'd_8_0',
#        'd_8_1', 'd_8_2', 'd_8_3', 'd_9_0', 'd_9_1', 'd_9_2', 'd_9_3',
#        'scalar_coupling_constant'],
#       dtype='object')
# Index(['atom_2', 'atom_3', 'atom_4', 'atom_5', 'atom_6', 'atom_7', 'atom_8',
#        'atom_9', 'd_1_0', 'd_2_0', 'd_2_1', 'd_3_0', 'd_3_1', 'd_3_2', 'd_4_0',
#        'd_4_1', 'd_4_2', 'd_4_3', 'd_5_0', 'd_5_1', 'd_5_2', 'd_5_3', 'd_6_0',
#        'd_6_1', 'd_6_2', 'd_6_3', 'd_7_0', 'd_7_1', 'd_7_2', 'd_7_3', 'd_8_0',
#        'd_8_1', 'd_8_2', 'd_8_3', 'd_9_0', 'd_9_1', 'd_9_2', 'd_9_3'],
#       dtype='object')
# Training until validation scores don't improve for 100 rounds.
# [1000]	training's l1: 1.02205	valid_1's l1: 1.07741
# [2000]	training's l1: 0.855662	valid_1's l1: 0.946207
# [3000]	training's l1: 0.762742	valid_1's l1: 0.880383
# [4000]	training's l1: 0.696874	valid_1's l1: 0.836772
# [5000]	training's l1: 0.646503	valid_1's l1: 0.806085
# [6000]	training's l1: 0.605669	valid_1's l1: 0.782499
# [7000]	training's l1: 0.571427	valid_1's l1: 0.763782
# [8000]	training's l1: 0.542114	valid_1's l1: 0.748731
# [9000]	training's l1: 0.515955	valid_1's l1: 0.735687
# [10000]	training's l1: 0.493149	valid_1's l1: 0.72475
# Did not meet early stopping. Best iteration is:
# [10000]	training's l1: 0.493149	valid_1's l1: 0.72475
# 1JHC Fold 0, logMAE: -0.3219282999441538
# Training until validation scores don't improve for 100 rounds.
# [1000]	training's l1: 1.0255	valid_1's l1: 1.07846
# [2000]	training's l1: 0.859481	valid_1's l1: 0.946995
# [3000]	training's l1: 0.764148	valid_1's l1: 0.878582
# [4000]	training's l1: 0.698265	valid_1's l1: 0.834789
# [5000]	training's l1: 0.647751	valid_1's l1: 0.803224
# [6000]	training's l1: 0.607635	valid_1's l1: 0.779994
# [7000]	training's l1: 0.573716	valid_1's l1: 0.761107
# [8000]	training's l1: 0.544025	valid_1's l1: 0.745323
# [9000]	training's l1: 0.518271	valid_1's l1: 0.731906
# [10000]	training's l1: 0.495358	valid_1's l1: 0.72058
# Did not meet early stopping. Best iteration is:
# [10000]	training's l1: 0.495358	valid_1's l1: 0.72058
# 1JHC Fold 1, logMAE: -0.3276987331362578
# Training until validation scores don't improve for 100 rounds.
# [1000]	training's l1: 1.02546	valid_1's l1: 1.08079
# [2000]	training's l1: 0.857909	valid_1's l1: 0.947977
# [3000]	training's l1: 0.762214	valid_1's l1: 0.878806
# [4000]	training's l1: 0.696691	valid_1's l1: 0.835716
# [5000]	training's l1: 0.646359	valid_1's l1: 0.805329
# [6000]	training's l1: 0.605476	valid_1's l1: 0.781803
# [7000]	training's l1: 0.571288	valid_1's l1: 0.76297
# [8000]	training's l1: 0.541845	valid_1's l1: 0.747496
# [9000]	training's l1: 0.515852	valid_1's l1: 0.73424
# [10000]	training's l1: 0.492809	valid_1's l1: 0.723158
# Did not meet early stopping. Best iteration is:
# [10000]	training's l1: 0.492809	valid_1's l1: 0.723158
# 1JHC Fold 2, logMAE: -0.3241269718039872
# Training until validation scores don't improve for 100 rounds.
# [1000]	training's l1: 1.02255	valid_1's l1: 1.08241
# [2000]	training's l1: 0.857061	valid_1's l1: 0.949387
# [3000]	training's l1: 0.763002	valid_1's l1: 0.881003
# [4000]	training's l1: 0.697039	valid_1's l1: 0.836643
# [5000]	training's l1: 0.646663	valid_1's l1: 0.805032
# [6000]	training's l1: 0.60636	valid_1's l1: 0.781162
# [7000]	training's l1: 0.57291	valid_1's l1: 0.762536
# [8000]	training's l1: 0.543636	valid_1's l1: 0.747162
# [9000]	training's l1: 0.51781	valid_1's l1: 0.733907
# [10000]	training's l1: 0.494949	valid_1's l1: 0.722837
# Did not meet early stopping. Best iteration is:
# [10000]	training's l1: 0.494949	valid_1's l1: 0.722837
# 1JHC Fold 3, logMAE: -0.32457133335468186
# Training until validation scores don't improve for 100 rounds.
# [1000]	training's l1: 1.02023	valid_1's l1: 1.07988
# [2000]	training's l1: 0.856797	valid_1's l1: 0.948735
# [3000]	training's l1: 0.762771	valid_1's l1: 0.879985
# [4000]	training's l1: 0.697084	valid_1's l1: 0.835657
# [5000]	training's l1: 0.647144	valid_1's l1: 0.804412
# [6000]	training's l1: 0.606324	valid_1's l1: 0.780245
# [7000]	training's l1: 0.57194	valid_1's l1: 0.761125
# [8000]	training's l1: 0.542623	valid_1's l1: 0.745248
# [9000]	training's l1: 0.51644	valid_1's l1: 0.731801
# [10000]	training's l1: 0.493265	valid_1's l1: 0.720689
# Did not meet early stopping. Best iteration is:
# [10000]	training's l1: 0.493265	valid_1's l1: 0.720689
# 1JHC Fold 4, logMAE: -0.3275480640153759
# *** Training Model for 2JHH ***
# Index(['atom_2', 'atom_3', 'atom_4', 'atom_5', 'atom_6', 'atom_7', 'atom_8',
#        'd_1_0', 'd_2_0', 'd_2_1', 'd_3_0', 'd_3_1', 'd_3_2', 'd_4_0', 'd_4_1',
#        'd_4_2', 'd_4_3', 'd_5_0', 'd_5_1', 'd_5_2', 'd_5_3', 'd_6_0', 'd_6_1',
#        'd_6_2', 'd_6_3', 'd_7_0', 'd_7_1', 'd_7_2', 'd_7_3', 'd_8_0', 'd_8_1',
#        'd_8_2', 'd_8_3', 'scalar_coupling_constant'],
#       dtype='object')
# Index(['atom_2', 'atom_3', 'atom_4', 'atom_5', 'atom_6', 'atom_7', 'atom_8',
#        'd_1_0', 'd_2_0', 'd_2_1', 'd_3_0', 'd_3_1', 'd_3_2', 'd_4_0', 'd_4_1',
#        'd_4_2', 'd_4_3', 'd_5_0', 'd_5_1', 'd_5_2', 'd_5_3', 'd_6_0', 'd_6_1',
#        'd_6_2', 'd_6_3', 'd_7_0', 'd_7_1', 'd_7_2', 'd_7_3', 'd_8_0', 'd_8_1',
#        'd_8_2', 'd_8_3'],
#       dtype='object')
# Training until validation scores don't improve for 100 rounds.
# [1000]	training's l1: 0.204562	valid_1's l1: 0.230214
# [2000]	training's l1: 0.163579	valid_1's l1: 0.200263
# [3000]	training's l1: 0.141144	valid_1's l1: 0.185519
# [4000]	training's l1: 0.125954	valid_1's l1: 0.176635
# [5000]	training's l1: 0.114345	valid_1's l1: 0.170378
# [6000]	training's l1: 0.105261	valid_1's l1: 0.165762
# [7000]	training's l1: 0.0977834	valid_1's l1: 0.162177
# [8000]	training's l1: 0.0912976	valid_1's l1: 0.159305
# [9000]	training's l1: 0.0857221	valid_1's l1: 0.156918
# [10000]	training's l1: 0.080838	valid_1's l1: 0.154928
# Did not meet early stopping. Best iteration is:
# [10000]	training's l1: 0.080838	valid_1's l1: 0.154928
# 2JHH Fold 0, logMAE: -1.8647920197374384
# Training until validation scores don't improve for 100 rounds.
# [1000]	training's l1: 0.204089	valid_1's l1: 0.227485
# [2000]	training's l1: 0.16347	valid_1's l1: 0.198662
# [3000]	training's l1: 0.140613	valid_1's l1: 0.184156
# [4000]	training's l1: 0.125304	valid_1's l1: 0.175273
# [5000]	training's l1: 0.11382	valid_1's l1: 0.16917
# [6000]	training's l1: 0.104735	valid_1's l1: 0.164527
# [7000]	training's l1: 0.0971995	valid_1's l1: 0.160882
# [8000]	training's l1: 0.0909431	valid_1's l1: 0.158054
# [9000]	training's l1: 0.0854861	valid_1's l1: 0.155682
# [10000]	training's l1: 0.0806423	valid_1's l1: 0.153722
# Did not meet early stopping. Best iteration is:
# [10000]	training's l1: 0.0806423	valid_1's l1: 0.153722
# 2JHH Fold 1, logMAE: -1.8726111571637412
# Training until validation scores don't improve for 100 rounds.
# [1000]	training's l1: 0.204545	valid_1's l1: 0.227733
# [2000]	training's l1: 0.163438	valid_1's l1: 0.1977
# [3000]	training's l1: 0.141169	valid_1's l1: 0.183705
# [4000]	training's l1: 0.125875	valid_1's l1: 0.174865
# [5000]	training's l1: 0.114335	valid_1's l1: 0.168757
# [6000]	training's l1: 0.105119	valid_1's l1: 0.164011
# [7000]	training's l1: 0.0974429	valid_1's l1: 0.160377
# [8000]	training's l1: 0.0910718	valid_1's l1: 0.157557
# [9000]	training's l1: 0.085478	valid_1's l1: 0.155123
# [10000]	training's l1: 0.0806689	valid_1's l1: 0.153179
# Did not meet early stopping. Best iteration is:
# [10000]	training's l1: 0.0806689	valid_1's l1: 0.153179
# 2JHH Fold 2, logMAE: -1.8761470570732355
# Training until validation scores don't improve for 100 rounds.
# [1000]	training's l1: 0.205001	valid_1's l1: 0.230634
# [2000]	training's l1: 0.163673	valid_1's l1: 0.201002
# [3000]	training's l1: 0.140894	valid_1's l1: 0.18634
# [4000]	training's l1: 0.125659	valid_1's l1: 0.177534
# [5000]	training's l1: 0.114106	valid_1's l1: 0.171307
# [6000]	training's l1: 0.104818	valid_1's l1: 0.166518
# [7000]	training's l1: 0.0972019	valid_1's l1: 0.16286
# [8000]	training's l1: 0.090776	valid_1's l1: 0.159939
# [9000]	training's l1: 0.0853696	valid_1's l1: 0.157534
# [10000]	training's l1: 0.0805161	valid_1's l1: 0.15548
# Did not meet early stopping. Best iteration is:
# [10000]	training's l1: 0.0805161	valid_1's l1: 0.15548
# 2JHH Fold 3, logMAE: -1.861236330032827
# Training until validation scores don't improve for 100 rounds.
# [1000]	training's l1: 0.204328	valid_1's l1: 0.227847
# [2000]	training's l1: 0.163261	valid_1's l1: 0.197886
# [3000]	training's l1: 0.140672	valid_1's l1: 0.183318
# [4000]	training's l1: 0.125366	valid_1's l1: 0.17431
# [5000]	training's l1: 0.11397	valid_1's l1: 0.168139
# [6000]	training's l1: 0.104952	valid_1's l1: 0.163623
# [7000]	training's l1: 0.0973615	valid_1's l1: 0.159912
# [8000]	training's l1: 0.0909563	valid_1's l1: 0.157091
# [9000]	training's l1: 0.085459	valid_1's l1: 0.154735
# [10000]	training's l1: 0.0805905	valid_1's l1: 0.152755
# Did not meet early stopping. Best iteration is:
# [10000]	training's l1: 0.0805905	valid_1's l1: 0.152755
# 2JHH Fold 4, logMAE: -1.878921546175611
# *** Training Model for 2JHN ***
# Index(['atom_2', 'atom_3', 'atom_4', 'atom_5', 'atom_6', 'atom_7', 'atom_8',
#        'd_1_0', 'd_2_0', 'd_2_1', 'd_3_0', 'd_3_1', 'd_3_2', 'd_4_0', 'd_4_1',
#        'd_4_2', 'd_4_3', 'd_5_0', 'd_5_1', 'd_5_2', 'd_5_3', 'd_6_0', 'd_6_1',
#        'd_6_2', 'd_6_3', 'd_7_0', 'd_7_1', 'd_7_2', 'd_7_3', 'd_8_0', 'd_8_1',
#        'd_8_2', 'd_8_3', 'scalar_coupling_constant'],
#       dtype='object')
# Index(['atom_2', 'atom_3', 'atom_4', 'atom_5', 'atom_6', 'atom_7', 'atom_8',
#        'd_1_0', 'd_2_0', 'd_2_1', 'd_3_0', 'd_3_1', 'd_3_2', 'd_4_0', 'd_4_1',
#        'd_4_2', 'd_4_3', 'd_5_0', 'd_5_1', 'd_5_2', 'd_5_3', 'd_6_0', 'd_6_1',
#        'd_6_2', 'd_6_3', 'd_7_0', 'd_7_1', 'd_7_2', 'd_7_3', 'd_8_0', 'd_8_1',
#        'd_8_2', 'd_8_3'],
#       dtype='object')
# Training until validation scores don't improve for 100 rounds.
# [1000]	training's l1: 0.137361	valid_1's l1: 0.174071
# [2000]	training's l1: 0.10384	valid_1's l1: 0.152405
# [3000]	training's l1: 0.0856099	valid_1's l1: 0.142386
# [4000]	training's l1: 0.073778	valid_1's l1: 0.136489
# [5000]	training's l1: 0.0651097	valid_1's l1: 0.132513
# [6000]	training's l1: 0.0584081	valid_1's l1: 0.129679
# [7000]	training's l1: 0.053123	valid_1's l1: 0.127621
# [8000]	training's l1: 0.0487372	valid_1's l1: 0.126052
# [9000]	training's l1: 0.0451292	valid_1's l1: 0.124717
# [10000]	training's l1: 0.0420009	valid_1's l1: 0.123696
# Did not meet early stopping. Best iteration is:
# [10000]	training's l1: 0.0420009	valid_1's l1: 0.123696
# 2JHN Fold 0, logMAE: -2.0899309643641115
# Training until validation scores don't improve for 100 rounds.
# [1000]	training's l1: 0.137976	valid_1's l1: 0.172601
# [2000]	training's l1: 0.103863	valid_1's l1: 0.150505
# [3000]	training's l1: 0.085925	valid_1's l1: 0.140614
# [4000]	training's l1: 0.0739014	valid_1's l1: 0.134636
# [5000]	training's l1: 0.0652513	valid_1's l1: 0.130774
# [6000]	training's l1: 0.0586432	valid_1's l1: 0.12802
# [7000]	training's l1: 0.0532869	valid_1's l1: 0.126003
# [8000]	training's l1: 0.0489657	valid_1's l1: 0.124406
# [9000]	training's l1: 0.0453109	valid_1's l1: 0.123133
# [10000]	training's l1: 0.042225	valid_1's l1: 0.122088
# Did not meet early stopping. Best iteration is:
# [10000]	training's l1: 0.042225	valid_1's l1: 0.122088
# 2JHN Fold 1, logMAE: -2.1030144613412247
# Training until validation scores don't improve for 100 rounds.
# [1000]	training's l1: 0.138458	valid_1's l1: 0.170813
# [2000]	training's l1: 0.104408	valid_1's l1: 0.148971
# [3000]	training's l1: 0.0863267	valid_1's l1: 0.138997
# [4000]	training's l1: 0.0744193	valid_1's l1: 0.1332
# [5000]	training's l1: 0.065638	valid_1's l1: 0.129421
# [6000]	training's l1: 0.058982	valid_1's l1: 0.12678
# [7000]	training's l1: 0.0535315	valid_1's l1: 0.124801
# [8000]	training's l1: 0.0490972	valid_1's l1: 0.12327
# [9000]	training's l1: 0.0454401	valid_1's l1: 0.122046
# [10000]	training's l1: 0.0423122	valid_1's l1: 0.121017
# Did not meet early stopping. Best iteration is:
# [10000]	training's l1: 0.0423122	valid_1's l1: 0.121017
# 2JHN Fold 2, logMAE: -2.1118204382462142
# Training until validation scores don't improve for 100 rounds.
# [1000]	training's l1: 0.137261	valid_1's l1: 0.171533
# [2000]	training's l1: 0.103567	valid_1's l1: 0.14916
# [3000]	training's l1: 0.0855368	valid_1's l1: 0.13902
# [4000]	training's l1: 0.0737797	valid_1's l1: 0.13317
# [5000]	training's l1: 0.0651256	valid_1's l1: 0.129318
# [6000]	training's l1: 0.0585173	valid_1's l1: 0.126577
# [7000]	training's l1: 0.0531875	valid_1's l1: 0.124608
# [8000]	training's l1: 0.0488235	valid_1's l1: 0.122939
# [9000]	training's l1: 0.0451657	valid_1's l1: 0.121663
# [10000]	training's l1: 0.0420866	valid_1's l1: 0.120623
# Did not meet early stopping. Best iteration is:
# [10000]	training's l1: 0.0420866	valid_1's l1: 0.120623
# 2JHN Fold 3, logMAE: -2.1150853618765204
# Training until validation scores don't improve for 100 rounds.
# [1000]	training's l1: 0.137943	valid_1's l1: 0.17158
# [2000]	training's l1: 0.103865	valid_1's l1: 0.149818
# [3000]	training's l1: 0.0857478	valid_1's l1: 0.1399
# [4000]	training's l1: 0.0737989	valid_1's l1: 0.134143
# [5000]	training's l1: 0.0650704	valid_1's l1: 0.130315
# [6000]	training's l1: 0.0583793	valid_1's l1: 0.127637
# [7000]	training's l1: 0.0530752	valid_1's l1: 0.125693
# [8000]	training's l1: 0.0487341	valid_1's l1: 0.124116
# [9000]	training's l1: 0.0451472	valid_1's l1: 0.122935
# [10000]	training's l1: 0.0420784	valid_1's l1: 0.12196
# Did not meet early stopping. Best iteration is:
# [10000]	training's l1: 0.0420784	valid_1's l1: 0.12196
# 2JHN Fold 4, logMAE: -2.104063668552527
# *** Training Model for 2JHC ***
# Index(['atom_2', 'atom_3', 'atom_4', 'atom_5', 'atom_6', 'atom_7', 'atom_8',
#        'd_1_0', 'd_2_0', 'd_2_1', 'd_3_0', 'd_3_1', 'd_3_2', 'd_4_0', 'd_4_1',
#        'd_4_2', 'd_4_3', 'd_5_0', 'd_5_1', 'd_5_2', 'd_5_3', 'd_6_0', 'd_6_1',
#        'd_6_2', 'd_6_3', 'd_7_0', 'd_7_1', 'd_7_2', 'd_7_3', 'd_8_0', 'd_8_1',
#        'd_8_2', 'd_8_3', 'scalar_coupling_constant'],
#       dtype='object')
# Index(['atom_2', 'atom_3', 'atom_4', 'atom_5', 'atom_6', 'atom_7', 'atom_8',
#        'd_1_0', 'd_2_0', 'd_2_1', 'd_3_0', 'd_3_1', 'd_3_2', 'd_4_0', 'd_4_1',
#        'd_4_2', 'd_4_3', 'd_5_0', 'd_5_1', 'd_5_2', 'd_5_3', 'd_6_0', 'd_6_1',
#        'd_6_2', 'd_6_3', 'd_7_0', 'd_7_1', 'd_7_2', 'd_7_3', 'd_8_0', 'd_8_1',
#        'd_8_2', 'd_8_3'],
#       dtype='object')
# Training until validation scores don't improve for 100 rounds.
# [1000]	training's l1: 0.439159	valid_1's l1: 0.4558
# [2000]	training's l1: 0.367511	valid_1's l1: 0.393369
# [3000]	training's l1: 0.328275	valid_1's l1: 0.361137
# [4000]	training's l1: 0.301833	valid_1's l1: 0.340758
# [5000]	training's l1: 0.282136	valid_1's l1: 0.326339
# [6000]	training's l1: 0.265699	valid_1's l1: 0.314631
# [7000]	training's l1: 0.252357	valid_1's l1: 0.305529
# [8000]	training's l1: 0.240998	valid_1's l1: 0.297978
# [9000]	training's l1: 0.230916	valid_1's l1: 0.291452
# [10000]	training's l1: 0.222103	valid_1's l1: 0.285953
# Did not meet early stopping. Best iteration is:
# [10000]	training's l1: 0.222103	valid_1's l1: 0.285953
# 2JHC Fold 0, logMAE: -1.2519276991923274
# Training until validation scores don't improve for 100 rounds.
# [1000]	training's l1: 0.441187	valid_1's l1: 0.457085
# [2000]	training's l1: 0.367686	valid_1's l1: 0.392556
# [3000]	training's l1: 0.328423	valid_1's l1: 0.360199
# [4000]	training's l1: 0.302239	valid_1's l1: 0.340134
# [5000]	training's l1: 0.282163	valid_1's l1: 0.325382
# [6000]	training's l1: 0.265871	valid_1's l1: 0.31387
# [7000]	training's l1: 0.25242	valid_1's l1: 0.304806
# [8000]	training's l1: 0.241109	valid_1's l1: 0.297273
# [9000]	training's l1: 0.231012	valid_1's l1: 0.29077
# [10000]	training's l1: 0.222235	valid_1's l1: 0.285303
# Did not meet early stopping. Best iteration is:
# [10000]	training's l1: 0.222235	valid_1's l1: 0.285303
# 2JHC Fold 1, logMAE: -1.2542040639183882
# Training until validation scores don't improve for 100 rounds.
# [1000]	training's l1: 0.438735	valid_1's l1: 0.453375
# [2000]	training's l1: 0.367227	valid_1's l1: 0.390963
# [3000]	training's l1: 0.328027	valid_1's l1: 0.3591
# [4000]	training's l1: 0.30171	valid_1's l1: 0.338766
# [5000]	training's l1: 0.28164	valid_1's l1: 0.323894
# [6000]	training's l1: 0.26572	valid_1's l1: 0.312647
# [7000]	training's l1: 0.252203	valid_1's l1: 0.303354
# [8000]	training's l1: 0.240975	valid_1's l1: 0.295964
# [9000]	training's l1: 0.230952	valid_1's l1: 0.289584
# [10000]	training's l1: 0.222086	valid_1's l1: 0.284011
# Did not meet early stopping. Best iteration is:
# [10000]	training's l1: 0.222086	valid_1's l1: 0.284011
# 2JHC Fold 2, logMAE: -1.2587409638813143
# Training until validation scores don't improve for 100 rounds.
# [1000]	training's l1: 0.43944	valid_1's l1: 0.45638
# [2000]	training's l1: 0.366763	valid_1's l1: 0.392913
# [3000]	training's l1: 0.328069	valid_1's l1: 0.361382
# [4000]	training's l1: 0.301578	valid_1's l1: 0.340814
# [5000]	training's l1: 0.281304	valid_1's l1: 0.325668
# [6000]	training's l1: 0.265164	valid_1's l1: 0.314166
# [7000]	training's l1: 0.251872	valid_1's l1: 0.305074
# [8000]	training's l1: 0.240454	valid_1's l1: 0.297508
# [9000]	training's l1: 0.230693	valid_1's l1: 0.291287
# [10000]	training's l1: 0.221892	valid_1's l1: 0.285797
# Did not meet early stopping. Best iteration is:
# [10000]	training's l1: 0.221892	valid_1's l1: 0.285797
# 2JHC Fold 3, logMAE: -1.2524751629072381
# Training until validation scores don't improve for 100 rounds.
# [1000]	training's l1: 0.438519	valid_1's l1: 0.45555
# [2000]	training's l1: 0.36797	valid_1's l1: 0.394467
# [3000]	training's l1: 0.328834	valid_1's l1: 0.362381
# [4000]	training's l1: 0.302383	valid_1's l1: 0.341725
# [5000]	training's l1: 0.282315	valid_1's l1: 0.326794
# [6000]	training's l1: 0.266368	valid_1's l1: 0.315316
# [7000]	training's l1: 0.252975	valid_1's l1: 0.30599
# [8000]	training's l1: 0.241412	valid_1's l1: 0.29819
# [9000]	training's l1: 0.231349	valid_1's l1: 0.291719
# [10000]	training's l1: 0.222401	valid_1's l1: 0.286052
# Did not meet early stopping. Best iteration is:
# [10000]	training's l1: 0.222401	valid_1's l1: 0.286052
# 2JHC Fold 4, logMAE: -1.2515827504528194
# *** Training Model for 3JHH ***
# Index(['atom_2', 'atom_3', 'atom_4', 'atom_5', 'atom_6', 'atom_7', 'atom_8',
#        'd_1_0', 'd_2_0', 'd_2_1', 'd_3_0', 'd_3_1', 'd_3_2', 'd_4_0', 'd_4_1',
#        'd_4_2', 'd_4_3', 'd_5_0', 'd_5_1', 'd_5_2', 'd_5_3', 'd_6_0', 'd_6_1',
#        'd_6_2', 'd_6_3', 'd_7_0', 'd_7_1', 'd_7_2', 'd_7_3', 'd_8_0', 'd_8_1',
#        'd_8_2', 'd_8_3', 'scalar_coupling_constant'],
#       dtype='object')
# Index(['atom_2', 'atom_3', 'atom_4', 'atom_5', 'atom_6', 'atom_7', 'atom_8',
#        'd_1_0', 'd_2_0', 'd_2_1', 'd_3_0', 'd_3_1', 'd_3_2', 'd_4_0', 'd_4_1',
#        'd_4_2', 'd_4_3', 'd_5_0', 'd_5_1', 'd_5_2', 'd_5_3', 'd_6_0', 'd_6_1',
#        'd_6_2', 'd_6_3', 'd_7_0', 'd_7_1', 'd_7_2', 'd_7_3', 'd_8_0', 'd_8_1',
#        'd_8_2', 'd_8_3'],
#       dtype='object')
# Training until validation scores don't improve for 100 rounds.
# [1000]	training's l1: 0.245754	valid_1's l1: 0.259143
# [2000]	training's l1: 0.199642	valid_1's l1: 0.221271
# [3000]	training's l1: 0.174578	valid_1's l1: 0.202418
# [4000]	training's l1: 0.157927	valid_1's l1: 0.190753
# [5000]	training's l1: 0.145347	valid_1's l1: 0.182423
# [6000]	training's l1: 0.135152	valid_1's l1: 0.176134
# [7000]	training's l1: 0.126884	valid_1's l1: 0.171284
# [8000]	training's l1: 0.119907	valid_1's l1: 0.16742
# [9000]	training's l1: 0.113874	valid_1's l1: 0.164165
# [10000]	training's l1: 0.108471	valid_1's l1: 0.161349
# Did not meet early stopping. Best iteration is:
# [10000]	training's l1: 0.108471	valid_1's l1: 0.161349
# 3JHH Fold 0, logMAE: -1.8241864966359016
# Training until validation scores don't improve for 100 rounds.
# [1000]	training's l1: 0.244691	valid_1's l1: 0.260515
# [2000]	training's l1: 0.199012	valid_1's l1: 0.222737
# [3000]	training's l1: 0.174264	valid_1's l1: 0.204094
# [4000]	training's l1: 0.157567	valid_1's l1: 0.192377
# [5000]	training's l1: 0.145205	valid_1's l1: 0.184272
# [6000]	training's l1: 0.13524	valid_1's l1: 0.178011
# [7000]	training's l1: 0.127022	valid_1's l1: 0.173164
# [8000]	training's l1: 0.12001	valid_1's l1: 0.169286
# [9000]	training's l1: 0.113933	valid_1's l1: 0.165943
# [10000]	training's l1: 0.108573	valid_1's l1: 0.163059
# Did not meet early stopping. Best iteration is:
# [10000]	training's l1: 0.108573	valid_1's l1: 0.163059
# 3JHH Fold 1, logMAE: -1.8136457898250358
# Training until validation scores don't improve for 100 rounds.
# [1000]	training's l1: 0.245723	valid_1's l1: 0.262434
# [2000]	training's l1: 0.199924	valid_1's l1: 0.224222
# [3000]	training's l1: 0.175274	valid_1's l1: 0.205254
# [4000]	training's l1: 0.158405	valid_1's l1: 0.193336
# [5000]	training's l1: 0.145508	valid_1's l1: 0.184752
# [6000]	training's l1: 0.135351	valid_1's l1: 0.178326
# [7000]	training's l1: 0.126929	valid_1's l1: 0.173355
# [8000]	training's l1: 0.119786	valid_1's l1: 0.169289
# [9000]	training's l1: 0.113661	valid_1's l1: 0.165981
# [10000]	training's l1: 0.108264	valid_1's l1: 0.16312
# Did not meet early stopping. Best iteration is:
# [10000]	training's l1: 0.108264	valid_1's l1: 0.16312
# 3JHH Fold 2, logMAE: -1.8132695018468645
# Training until validation scores don't improve for 100 rounds.
# [1000]	training's l1: 0.243336	valid_1's l1: 0.260745
# [2000]	training's l1: 0.198303	valid_1's l1: 0.223509
# [3000]	training's l1: 0.174042	valid_1's l1: 0.20522
# [4000]	training's l1: 0.157236	valid_1's l1: 0.193337
# [5000]	training's l1: 0.14477	valid_1's l1: 0.185122
# [6000]	training's l1: 0.134782	valid_1's l1: 0.178832
# [7000]	training's l1: 0.126632	valid_1's l1: 0.173987
# [8000]	training's l1: 0.119623	valid_1's l1: 0.169966
# [9000]	training's l1: 0.113556	valid_1's l1: 0.166567
# [10000]	training's l1: 0.10809	valid_1's l1: 0.163692
# Did not meet early stopping. Best iteration is:
# [10000]	training's l1: 0.10809	valid_1's l1: 0.163692
# 3JHH Fold 3, logMAE: -1.8097704486735635
# Training until validation scores don't improve for 100 rounds.
# [1000]	training's l1: 0.245368	valid_1's l1: 0.261062
# [2000]	training's l1: 0.199525	valid_1's l1: 0.223005
# [3000]	training's l1: 0.174611	valid_1's l1: 0.203988
# [4000]	training's l1: 0.157664	valid_1's l1: 0.192082
# [5000]	training's l1: 0.145188	valid_1's l1: 0.183745
# [6000]	training's l1: 0.135363	valid_1's l1: 0.177602
# [7000]	training's l1: 0.126978	valid_1's l1: 0.172567
# [8000]	training's l1: 0.119898	valid_1's l1: 0.168542
# [9000]	training's l1: 0.11376	valid_1's l1: 0.165199
# [10000]	training's l1: 0.108305	valid_1's l1: 0.162315
# Did not meet early stopping. Best iteration is:
# [10000]	training's l1: 0.108305	valid_1's l1: 0.162315
# 3JHH Fold 4, logMAE: -1.8182171938480363
# *** Training Model for 3JHC ***
# Index(['atom_2', 'atom_3', 'atom_4', 'atom_5', 'atom_6', 'atom_7', 'atom_8',
#        'atom_9', 'd_1_0', 'd_2_0', 'd_2_1', 'd_3_0', 'd_3_1', 'd_3_2', 'd_4_0',
#        'd_4_1', 'd_4_2', 'd_4_3', 'd_5_0', 'd_5_1', 'd_5_2', 'd_5_3', 'd_6_0',
#        'd_6_1', 'd_6_2', 'd_6_3', 'd_7_0', 'd_7_1', 'd_7_2', 'd_7_3', 'd_8_0',
#        'd_8_1', 'd_8_2', 'd_8_3', 'd_9_0', 'd_9_1', 'd_9_2', 'd_9_3',
#        'scalar_coupling_constant'],
#       dtype='object')
# Index(['atom_2', 'atom_3', 'atom_4', 'atom_5', 'atom_6', 'atom_7', 'atom_8',
#        'atom_9', 'd_1_0', 'd_2_0', 'd_2_1', 'd_3_0', 'd_3_1', 'd_3_2', 'd_4_0',
#        'd_4_1', 'd_4_2', 'd_4_3', 'd_5_0', 'd_5_1', 'd_5_2', 'd_5_3', 'd_6_0',
#        'd_6_1', 'd_6_2', 'd_6_3', 'd_7_0', 'd_7_1', 'd_7_2', 'd_7_3', 'd_8_0',
#        'd_8_1', 'd_8_2', 'd_8_3', 'd_9_0', 'd_9_1', 'd_9_2', 'd_9_3'],
#       dtype='object')
# Training until validation scores don't improve for 100 rounds.
# [1000]	training's l1: 0.493477	valid_1's l1: 0.505478
# [2000]	training's l1: 0.416108	valid_1's l1: 0.436207
# [3000]	training's l1: 0.373782	valid_1's l1: 0.400392
# [4000]	training's l1: 0.345348	valid_1's l1: 0.377528
# [5000]	training's l1: 0.323906	valid_1's l1: 0.361019
# [6000]	training's l1: 0.306355	valid_1's l1: 0.347864
# [7000]	training's l1: 0.292062	valid_1's l1: 0.337604
# [8000]	training's l1: 0.279796	valid_1's l1: 0.329017
# [9000]	training's l1: 0.269109	valid_1's l1: 0.321809
# [10000]	training's l1: 0.259607	valid_1's l1: 0.315647
# Did not meet early stopping. Best iteration is:
# [10000]	training's l1: 0.259607	valid_1's l1: 0.315647
# 3JHC Fold 0, logMAE: -1.1531321718469296
# Training until validation scores don't improve for 100 rounds.
# [1000]	training's l1: 0.493263	valid_1's l1: 0.508039
# [2000]	training's l1: 0.415877	valid_1's l1: 0.438458
# [3000]	training's l1: 0.374052	valid_1's l1: 0.402586
# [4000]	training's l1: 0.345516	valid_1's l1: 0.379054
# [5000]	training's l1: 0.32442	valid_1's l1: 0.362603
# [6000]	training's l1: 0.307176	valid_1's l1: 0.349573
# [7000]	training's l1: 0.292916	valid_1's l1: 0.33923
# [8000]	training's l1: 0.280781	valid_1's l1: 0.330727
# [9000]	training's l1: 0.269893	valid_1's l1: 0.323291
# [10000]	training's l1: 0.260302	valid_1's l1: 0.316982
# Did not meet early stopping. Best iteration is:
# [10000]	training's l1: 0.260302	valid_1's l1: 0.316982
# 3JHC Fold 1, logMAE: -1.1489107910169842
# Training until validation scores don't improve for 100 rounds.
# [1000]	training's l1: 0.492266	valid_1's l1: 0.504552
# [2000]	training's l1: 0.414973	valid_1's l1: 0.434799
# [3000]	training's l1: 0.374305	valid_1's l1: 0.400216
# [4000]	training's l1: 0.345709	valid_1's l1: 0.37716
# [5000]	training's l1: 0.324196	valid_1's l1: 0.360637
# [6000]	training's l1: 0.307016	valid_1's l1: 0.347875
# [7000]	training's l1: 0.29256	valid_1's l1: 0.337622
# [8000]	training's l1: 0.280258	valid_1's l1: 0.32917
# [9000]	training's l1: 0.269598	valid_1's l1: 0.321976
# [10000]	training's l1: 0.260319	valid_1's l1: 0.315938
# Did not meet early stopping. Best iteration is:
# [10000]	training's l1: 0.260319	valid_1's l1: 0.315938
# 3JHC Fold 2, logMAE: -1.1522106646728822
# Training until validation scores don't improve for 100 rounds.
# [1000]	training's l1: 0.491515	valid_1's l1: 0.503477
# [2000]	training's l1: 0.415487	valid_1's l1: 0.435971
# [3000]	training's l1: 0.373918	valid_1's l1: 0.400877
# [4000]	training's l1: 0.345572	valid_1's l1: 0.378293
# [5000]	training's l1: 0.324391	valid_1's l1: 0.362191
# [6000]	training's l1: 0.307336	valid_1's l1: 0.349579
# [7000]	training's l1: 0.293103	valid_1's l1: 0.339391
# [8000]	training's l1: 0.280744	valid_1's l1: 0.330892
# [9000]	training's l1: 0.270024	valid_1's l1: 0.323726
# [10000]	training's l1: 0.260564	valid_1's l1: 0.317614
# Did not meet early stopping. Best iteration is:
# [10000]	training's l1: 0.260564	valid_1's l1: 0.317614
# 3JHC Fold 3, logMAE: -1.1469169208803633
# Training until validation scores don't improve for 100 rounds.
# [1000]	training's l1: 0.492919	valid_1's l1: 0.50683
# [2000]	training's l1: 0.415756	valid_1's l1: 0.437525
# [3000]	training's l1: 0.37455	valid_1's l1: 0.402529
# [4000]	training's l1: 0.34551	valid_1's l1: 0.378923
# [5000]	training's l1: 0.32406	valid_1's l1: 0.362268
# [6000]	training's l1: 0.307086	valid_1's l1: 0.349687
# [7000]	training's l1: 0.292759	valid_1's l1: 0.339394
# [8000]	training's l1: 0.28039	valid_1's l1: 0.330863
# [9000]	training's l1: 0.269595	valid_1's l1: 0.323638
# [10000]	training's l1: 0.26008	valid_1's l1: 0.317452
# Did not meet early stopping. Best iteration is:
# [10000]	training's l1: 0.26008	valid_1's l1: 0.317452
# 3JHC Fold 4, logMAE: -1.1474277731827718
# *** Training Model for 3JHN ***
# Index(['atom_2', 'atom_3', 'atom_4', 'atom_5', 'atom_6', 'atom_7', 'atom_8',
#        'atom_9', 'd_1_0', 'd_2_0', 'd_2_1', 'd_3_0', 'd_3_1', 'd_3_2', 'd_4_0',
#        'd_4_1', 'd_4_2', 'd_4_3', 'd_5_0', 'd_5_1', 'd_5_2', 'd_5_3', 'd_6_0',
#        'd_6_1', 'd_6_2', 'd_6_3', 'd_7_0', 'd_7_1', 'd_7_2', 'd_7_3', 'd_8_0',
#        'd_8_1', 'd_8_2', 'd_8_3', 'd_9_0', 'd_9_1', 'd_9_2', 'd_9_3',
#        'scalar_coupling_constant'],
#       dtype='object')
# Index(['atom_2', 'atom_3', 'atom_4', 'atom_5', 'atom_6', 'atom_7', 'atom_8',
#        'atom_9', 'd_1_0', 'd_2_0', 'd_2_1', 'd_3_0', 'd_3_1', 'd_3_2', 'd_4_0',
#        'd_4_1', 'd_4_2', 'd_4_3', 'd_5_0', 'd_5_1', 'd_5_2', 'd_5_3', 'd_6_0',
#        'd_6_1', 'd_6_2', 'd_6_3', 'd_7_0', 'd_7_1', 'd_7_2', 'd_7_3', 'd_8_0',
#        'd_8_1', 'd_8_2', 'd_8_3', 'd_9_0', 'd_9_1', 'd_9_2', 'd_9_3'],
#       dtype='object')
# Training until validation scores don't improve for 100 rounds.
# [1000]	training's l1: 0.122136	valid_1's l1: 0.147032
# [2000]	training's l1: 0.0927083	valid_1's l1: 0.127211
# [3000]	training's l1: 0.0771965	valid_1's l1: 0.118221
# [4000]	training's l1: 0.0669922	valid_1's l1: 0.112874
# [5000]	training's l1: 0.0595828	valid_1's l1: 0.109468
# [6000]	training's l1: 0.0537213	valid_1's l1: 0.106855
# [7000]	training's l1: 0.0489085	valid_1's l1: 0.104916
# [8000]	training's l1: 0.044939	valid_1's l1: 0.103344
# [9000]	training's l1: 0.0415647	valid_1's l1: 0.102056
# [10000]	training's l1: 0.0387322	valid_1's l1: 0.101027
# Did not meet early stopping. Best iteration is:
# [10000]	training's l1: 0.0387322	valid_1's l1: 0.101027
# 3JHN Fold 0, logMAE: -2.2923662840332
# Training until validation scores don't improve for 100 rounds.
# [1000]	training's l1: 0.122938	valid_1's l1: 0.144968
# [2000]	training's l1: 0.0933467	valid_1's l1: 0.125307
# [3000]	training's l1: 0.077445	valid_1's l1: 0.11632
# [4000]	training's l1: 0.0670729	valid_1's l1: 0.111056
# [5000]	training's l1: 0.0593109	valid_1's l1: 0.107361
# [6000]	training's l1: 0.0534323	valid_1's l1: 0.104781
# [7000]	training's l1: 0.0486716	valid_1's l1: 0.102866
# [8000]	training's l1: 0.0447176	valid_1's l1: 0.101308
# [9000]	training's l1: 0.041425	valid_1's l1: 0.100052
# [10000]	training's l1: 0.0385746	valid_1's l1: 0.0990546
# Did not meet early stopping. Best iteration is:
# [10000]	training's l1: 0.0385746	valid_1's l1: 0.0990546
# 3JHN Fold 1, logMAE: -2.312084240583889
# Training until validation scores don't improve for 100 rounds.
# [1000]	training's l1: 0.121711	valid_1's l1: 0.147209
# [2000]	training's l1: 0.0925589	valid_1's l1: 0.127755
# [3000]	training's l1: 0.0771631	valid_1's l1: 0.118695
# [4000]	training's l1: 0.0669242	valid_1's l1: 0.11334
# [5000]	training's l1: 0.0594353	valid_1's l1: 0.109725
# [6000]	training's l1: 0.0535419	valid_1's l1: 0.107201
# [7000]	training's l1: 0.0487616	valid_1's l1: 0.105167
# [8000]	training's l1: 0.0448132	valid_1's l1: 0.103615
# [9000]	training's l1: 0.0415694	valid_1's l1: 0.102395
# [10000]	training's l1: 0.0387456	valid_1's l1: 0.101381
# Did not meet early stopping. Best iteration is:
# [10000]	training's l1: 0.0387456	valid_1's l1: 0.101381
# 3JHN Fold 2, logMAE: -2.2888660070459306
# Training until validation scores don't improve for 100 rounds.
# [1000]	training's l1: 0.121653	valid_1's l1: 0.146303
# [2000]	training's l1: 0.0924032	valid_1's l1: 0.126849
# [3000]	training's l1: 0.0768877	valid_1's l1: 0.117801
# [4000]	training's l1: 0.0666727	valid_1's l1: 0.112561
# [5000]	training's l1: 0.0590739	valid_1's l1: 0.108869
# [6000]	training's l1: 0.0531954	valid_1's l1: 0.106221
# [7000]	training's l1: 0.0484616	valid_1's l1: 0.104228
# [8000]	training's l1: 0.0445413	valid_1's l1: 0.102721
# [9000]	training's l1: 0.041251	valid_1's l1: 0.10146
# [10000]	training's l1: 0.0384408	valid_1's l1: 0.100452
# Did not meet early stopping. Best iteration is:
# [10000]	training's l1: 0.0384408	valid_1's l1: 0.100452
# 3JHN Fold 3, logMAE: -2.2980731452704375
# Training until validation scores don't improve for 100 rounds.
# [1000]	training's l1: 0.122151	valid_1's l1: 0.146572
# [2000]	training's l1: 0.0926996	valid_1's l1: 0.127183
# [3000]	training's l1: 0.0774338	valid_1's l1: 0.118366
# [4000]	training's l1: 0.0669945	valid_1's l1: 0.112951
# [5000]	training's l1: 0.0594067	valid_1's l1: 0.109351
# [6000]	training's l1: 0.0534953	valid_1's l1: 0.10672
# [7000]	training's l1: 0.0486687	valid_1's l1: 0.10469
# [8000]	training's l1: 0.0446922	valid_1's l1: 0.103063
# [9000]	training's l1: 0.0413797	valid_1's l1: 0.101832
# [10000]	training's l1: 0.0385824	valid_1's l1: 0.10084
# Did not meet early stopping. Best iteration is:
# [10000]	training's l1: 0.0385824	valid_1's l1: 0.10084
# 3JHN Fold 4, logMAE: -2.2942228570279073
# Wall time: 3h 28min 14s

# %%
pd.DataFrame({'type': list(cv_scores.keys()), 'cv_score': list(cv_scores.values())})
# Out:
#    type  cv_score
# 0  1JHN -1.104798
# 1  1JHC -0.325175
# 2  2JHH -1.870742
# 3  2JHN -2.104783
# 4  2JHC -1.253786
# 5  3JHH -1.815818
# 6  3JHC -1.149720
# 7  3JHN -2.297123

# %%
np.mean(list(cv_scores.values()))
# Out:
# -1.490242925007926

# %%
submission[submission['scalar_coupling_constant'] == 0].shape
# Out:
# (0, 1)

# %%
submission.to_csv('lgb_bayes_10k.csv')
