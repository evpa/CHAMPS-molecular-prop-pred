# %%
# %matplotlib inline

import pandas as pd
import numpy as np

import math
import gc
import copy

from sklearn.model_selection import KFold, train_test_split
from sklearn.metrics import mean_absolute_error

import matplotlib.pyplot as plt
import seaborn as sns

from lightgbm import LGBMRegressor

# %%
ATOMIC_NUMBERS = {
    'H': 1,
    'C': 6,
    'N': 7,
    'O': 8,
    'F': 9
}

# %%
# pd.set_option('display.max_colwidth', -1)
# pd.set_option('display.max_rows', 120)
# pd.set_option('display.max_columns', 120)

# %%
# train_dtypes = {
#     'molecule_name': 'category',
#     'atom_index_0': 'int8',
#     'atom_index_1': 'int8',
#     'type': 'category',
#     'scalar_coupling_constant': 'float32'
# }
train_csv = pd.read_csv('train.csv', index_col='id')
train_csv['molecule_index'] = train_csv.molecule_name.str.replace('dsgdb9nsd_', '').astype('int32')
train_csv = train_csv[['molecule_index', 'atom_index_0', 'atom_index_1', 'type', 'scalar_coupling_constant']]
# Out:
# C:\Users\Maynard\Anaconda3\lib\site-packages\numpy\lib\arraysetops.py:569: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)

# %%
train_csv.head()
# Out:
#     molecule_index  atom_index_0  atom_index_1  type  scalar_coupling_constant
# id
# 0                1             1             0  1JHC                   84.8076
# 1                1             1             2  2JHH                  -11.2570
# 2                1             1             3  2JHH                  -11.2548
# 3                1             1             4  2JHH                  -11.2543
# 4                1             2             0  1JHC                   84.8074

# %%
print('Shape: ', train_csv.shape)
print('Total: ', train_csv.memory_usage().sum())
train_csv.memory_usage()
# Out:
# Shape:  (4658147, 5)
# Total:  204958468
# Index                       37265176
# molecule_index              18632588
# atom_index_0                37265176
# atom_index_1                37265176
# type                        37265176
# scalar_coupling_constant    37265176
# dtype: int64

# %%
submission_csv = pd.read_csv('sample_submission.csv', index_col='id')

# %%
test_csv = pd.read_csv('test.csv', index_col='id')
test_csv['molecule_index'] = test_csv['molecule_name'].str.replace('dsgdb9nsd_', '').astype('int32')
test_csv = test_csv[['molecule_index', 'atom_index_0', 'atom_index_1', 'type']]

# %%
test_csv.head()
# Out:
#          molecule_index  atom_index_0  atom_index_1  type
# id
# 4658147               4             2             0  2JHC
# 4658148               4             2             1  1JHC
# 4658149               4             2             3  3JHH
# 4658150               4             3             0  1JHC
# 4658151               4             3             1  2JHC

# %%
# structures_dtypes = {
#     'molecule_name': 'category',
#     'atom_index': 'int8',
#     'atom': 'category',
#     'x': 'float32',
#     'y': 'float32',
#     'z': 'float32'
# }
structures_csv = pd.read_csv('structures.csv')
structures_csv['molecule_index'] = structures_csv.molecule_name.str.replace('dsgdb9nsd_', '').astype('int32')
structures_csv = structures_csv[['molecule_index', 'atom_index', 'atom', 'x', 'y', 'z']]

# %%
structures_csv['atom'] = structures_csv['atom'].replace(ATOMIC_NUMBERS).astype('int8')
structures_csv.head(10)
# Out:
#    molecule_index  atom_index  atom         x         y         z
# 0               1           0     6 -0.012698  1.085804  0.008001
# 1               1           1     1  0.002150 -0.006031  0.001976
# 2               1           2     1  1.011731  1.463751  0.000277
# 3               1           3     1 -0.540815  1.447527 -0.876644
# 4               1           4     1 -0.523814  1.437933  0.906397
# 5               2           0     7 -0.040426  1.024108  0.062564
# 6               2           1     1  0.017257  0.012545 -0.027377
# 7               2           2     1  0.915789  1.358745 -0.028758
# 8               2           3     1 -0.520278  1.343532 -0.775543
# 9               3           0     8 -0.034360  0.977540  0.007602

# %%
print('Shape: ', structures_csv.shape)
print('Total: ', structures_csv.memory_usage().sum())
structures_csv.memory_usage()
# Out:
# Shape:  (2358657, 6)
# Total:  87270389
# Index                   80
# molecule_index     9434628
# atom_index        18869256
# atom               2358657
# x                 18869256
# y                 18869256
# z                 18869256
# dtype: int64

# %%
def build_type_dataframes(base, structures, coupling_type):
    base = base[base['type'] == coupling_type].drop('type', axis=1).copy()
    base = base.reset_index()
    base['id'] = base['id'].astype('int32')
    structures = structures[structures['molecule_index'].isin(base['molecule_index'])]
    return base, structures

# %%
def add_coordinates(base, structures, index):
    df = pd.merge(base, structures, how='inner',
                  left_on=['molecule_index', f'atom_index_{index}'],
                  right_on=['molecule_index', 'atom_index']).drop(['atom_index'], axis=1)
    df = df.rename(columns={
        'atom': f'atom_{index}',
        'x': f'x_{index}',
        'y': f'y_{index}',
        'z': f'z_{index}'
    })
    return df

# %%
def add_atoms(base, atoms):
    df = pd.merge(base, atoms, how='inner',
                  on=['molecule_index', 'atom_index_0', 'atom_index_1'])
    return df

# %%
def merge_all_atoms(base, structures):
    df = pd.merge(base, structures, how='left',
                  left_on=['molecule_index'],
                  right_on=['molecule_index'])
    df = df[(df.atom_index_0 != df.atom_index) & (df.atom_index_1 != df.atom_index)]
    return df

# %%
def add_center(df):
    df['x_c'] = ((df['x_1'] + df['x_0']) * np.float32(0.5))
    df['y_c'] = ((df['y_1'] + df['y_0']) * np.float32(0.5))
    df['z_c'] = ((df['z_1'] + df['z_0']) * np.float32(0.5))

def add_distance_to_center(df):
    df['d_c'] = ((
        (df['x_c'] - df['x'])**np.float32(2) +
        (df['y_c'] - df['y'])**np.float32(2) + 
        (df['z_c'] - df['z'])**np.float32(2)
    )**np.float32(0.5))

def add_distance_between(df, suffix1, suffix2):
    df[f'd_{suffix1}_{suffix2}'] = ((
        (df[f'x_{suffix1}'] - df[f'x_{suffix2}'])**np.float32(2) +
        (df[f'y_{suffix1}'] - df[f'y_{suffix2}'])**np.float32(2) + 
        (df[f'z_{suffix1}'] - df[f'z_{suffix2}'])**np.float32(2)
    )**np.float32(0.5))

# %%
def add_distances(df):
    n_atoms = 1 + max([int(c.split('_')[1]) for c in df.columns if c.startswith('x_')])
    
    for i in range(1, n_atoms):
        for vi in range(min(4, i)):
            add_distance_between(df, i, vi)

# %%
def add_n_atoms(base, structures):
    dfs = structures['molecule_index'].value_counts().rename('n_atoms').to_frame()
    return pd.merge(base, dfs, left_on='molecule_index', right_index=True)

# %%
def build_couple_dataframe(some_csv, structures_csv, coupling_type, n_atoms=10):
    base, structures = build_type_dataframes(some_csv, structures_csv, coupling_type)
    base = add_coordinates(base, structures, 0)
    base = add_coordinates(base, structures, 1)
    
    base = base.drop(['atom_0', 'atom_1'], axis=1)
    atoms = base.drop('id', axis=1).copy()
    if 'scalar_coupling_constant' in some_csv:
        atoms = atoms.drop(['scalar_coupling_constant'], axis=1)
        
    add_center(atoms)
    atoms = atoms.drop(['x_0', 'y_0', 'z_0', 'x_1', 'y_1', 'z_1'], axis=1)

    atoms = merge_all_atoms(atoms, structures)
    
    add_distance_to_center(atoms)
    
    atoms = atoms.drop(['x_c', 'y_c', 'z_c', 'atom_index'], axis=1)
    atoms.sort_values(['molecule_index', 'atom_index_0', 'atom_index_1', 'd_c'], inplace=True)
    atom_groups = atoms.groupby(['molecule_index', 'atom_index_0', 'atom_index_1'])
    atoms['num'] = atom_groups.cumcount() + 2
    atoms = atoms.drop(['d_c'], axis=1)
    atoms = atoms[atoms['num'] < n_atoms]

    atoms = atoms.set_index(['molecule_index', 'atom_index_0', 'atom_index_1', 'num']).unstack()
    atoms.columns = [f'{col[0]}_{col[1]}' for col in atoms.columns]
    atoms = atoms.reset_index()
    
    # downcast back to int8
    for col in atoms.columns:
        if col.startswith('atom_'):
            atoms[col] = atoms[col].fillna(0).astype('int8')
            
    atoms['molecule_index'] = atoms['molecule_index'].astype('int32')
    
    full = add_atoms(base, atoms)
    add_distances(full)
    
    full.sort_values('id', inplace=True)
    
    return full

# %%
def take_n_atoms(df, n_atoms, four_start=4):
    labels = []
    for i in range(2, n_atoms):
        label = f'atom_{i}'
        labels.append(label)

    for i in range(n_atoms):
        num = min(i, 4) if i < four_start else 4
        for j in range(num):
            labels.append(f'd_{i}_{j}')
    if 'scalar_coupling_constant' in df:
        labels.append('scalar_coupling_constant')
    return df[labels]

# %%
# %%time
full = build_couple_dataframe(train_csv, structures_csv, '1JHN', n_atoms=10)
print(full.shape)
# Out:
# (43363, 73)
# Wall time: 4.9 s

# %%
full.columns
# Out:
# Index(['id', 'molecule_index', 'atom_index_0', 'atom_index_1',
#        'scalar_coupling_constant', 'x_0', 'y_0', 'z_0', 'x_1', 'y_1', 'z_1',
#        'atom_2', 'atom_3', 'atom_4', 'atom_5', 'atom_6', 'atom_7', 'atom_8',
#        'atom_9', 'x_2', 'x_3', 'x_4', 'x_5', 'x_6', 'x_7', 'x_8', 'x_9', 'y_2',
#        'y_3', 'y_4', 'y_5', 'y_6', 'y_7', 'y_8', 'y_9', 'z_2', 'z_3', 'z_4',
#        'z_5', 'z_6', 'z_7', 'z_8', 'z_9', 'd_1_0', 'd_2_0', 'd_2_1', 'd_3_0',
#        'd_3_1', 'd_3_2', 'd_4_0', 'd_4_1', 'd_4_2', 'd_4_3', 'd_5_0', 'd_5_1',
#        'd_5_2', 'd_5_3', 'd_6_0', 'd_6_1', 'd_6_2', 'd_6_3', 'd_7_0', 'd_7_1',
#        'd_7_2', 'd_7_3', 'd_8_0', 'd_8_1', 'd_8_2', 'd_8_3', 'd_9_0', 'd_9_1',
#        'd_9_2', 'd_9_3'],
#       dtype='object')

# %%
df = take_n_atoms(full, 7)
# LightGBM performs better with 0-s then with NaN-s
df = df.fillna(0)
df.columns
# Out:
# Index(['atom_2', 'atom_3', 'atom_4', 'atom_5', 'atom_6', 'd_1_0', 'd_2_0',
#        'd_2_1', 'd_3_0', 'd_3_1', 'd_3_2', 'd_4_0', 'd_4_1', 'd_4_2', 'd_4_3',
#        'd_5_0', 'd_5_1', 'd_5_2', 'd_5_3', 'd_6_0', 'd_6_1', 'd_6_2', 'd_6_3',
#        'scalar_coupling_constant'],
#       dtype='object')

# %%
X_data = df.drop(['scalar_coupling_constant'], axis=1).values.astype('float32')
y_data = df['scalar_coupling_constant'].values.astype('float32')

X_train, X_val, y_train, y_val = train_test_split(X_data, y_data, test_size=0.2, random_state=128)
X_train.shape, X_val.shape, y_train.shape, y_val.shape
# Out:
# ((34690, 23), (8673, 23), (34690,), (8673,))

# %%
LGB_PARAMS = {
    'objective': 'regression',
    'metric': 'mae',
    'verbosity': -1,
    'boosting_type': 'gbdt',
    'learning_rate': 0.1,
    'num_leaves': 128,
    'min_child_samples': 79,
    'max_depth': -1,
    'subsample_freq': 1,
    'subsample': 0.9,
    'bagging_seed': 11,
    'reg_alpha': 0.1,
    'reg_lambda': 0.3,
    'colsample_bytree': 1.0
}

# %%
def build_x_y_data(some_csv, coupling_type, n_atoms):
    full = build_couple_dataframe(some_csv, structures_csv, coupling_type, n_atoms=n_atoms)
    
    df = take_n_atoms(full, n_atoms)
    df = df.fillna(0)
    print(df.columns)
    
    if 'scalar_coupling_constant' in df:
        X_data = df.drop(['scalar_coupling_constant'], axis=1).values.astype('float32')
        y_data = df['scalar_coupling_constant'].values.astype('float32')
    else:
        X_data = df.values.astype('float32')
        y_data = None
    
    return X_data, y_data

# %%
def train_and_predict_for_one_coupling_type(coupling_type, submission, n_atoms, n_folds=5, n_splits=5, random_state=128):
    print(f'*** Training Model for {coupling_type} ***')
    
    X_data, y_data = build_x_y_data(train_csv, coupling_type, n_atoms)
    X_test, _ = build_x_y_data(test_csv, coupling_type, n_atoms)
    y_pred = np.zeros(X_test.shape[0], dtype='float32')

    cv_score = 0
    
    if n_folds > n_splits:
        n_splits = n_folds
    
    kfold = KFold(n_splits=n_splits, shuffle=True, random_state=random_state)

    for fold, (train_index, val_index) in enumerate(kfold.split(X_data, y_data)):
        if fold >= n_folds:
            break

        X_train, X_val = X_data[train_index], X_data[val_index]
        y_train, y_val = y_data[train_index], y_data[val_index]

        model = LGBMRegressor(**LGB_PARAMS, n_estimators=20000, n_jobs = -1)
        model.fit(X_train, y_train, 
            eval_set=[(X_train, y_train), (X_val, y_val)], eval_metric='mae',
            verbose=2000, early_stopping_rounds=100)

        y_val_pred = model.predict(X_val)
        val_score = np.log(mean_absolute_error(y_val, y_val_pred))
        print(f'{coupling_type} Fold {fold}, logMAE: {val_score}')
        
        cv_score += val_score / n_folds
        y_pred += model.predict(X_test) / n_folds
        
        
    submission.loc[test_csv['type'] == coupling_type, 'scalar_coupling_constant'] = y_pred
    return cv_score

# %%
# %%time

model_params = {
    '1JHN': 7,
    '1JHC': 10,
    '2JHH': 9,
    '2JHN': 9,
    '2JHC': 9,
    '3JHH': 9,
    '3JHC': 10,
    '3JHN': 10
}
N_FOLDS = 5
submission = submission_csv.copy()

cv_scores = {}
for coupling_type in model_params.keys():
    cv_score = train_and_predict_for_one_coupling_type(
        coupling_type, submission, n_atoms=model_params[coupling_type], n_folds=N_FOLDS)
    cv_scores[coupling_type] = cv_score
# Out:
# *** Training Model for 1JHN ***
# Index(['atom_2', 'atom_3', 'atom_4', 'atom_5', 'atom_6', 'd_1_0', 'd_2_0',
#        'd_2_1', 'd_3_0', 'd_3_1', 'd_3_2', 'd_4_0', 'd_4_1', 'd_4_2', 'd_4_3',
#        'd_5_0', 'd_5_1', 'd_5_2', 'd_5_3', 'd_6_0', 'd_6_1', 'd_6_2', 'd_6_3',
#        'scalar_coupling_constant'],
#       dtype='object')
# Index(['atom_2', 'atom_3', 'atom_4', 'atom_5', 'atom_6', 'd_1_0', 'd_2_0',
#        'd_2_1', 'd_3_0', 'd_3_1', 'd_3_2', 'd_4_0', 'd_4_1', 'd_4_2', 'd_4_3',
#        'd_5_0', 'd_5_1', 'd_5_2', 'd_5_3', 'd_6_0', 'd_6_1', 'd_6_2', 'd_6_3'],
#       dtype='object')
# Training until validation scores don't improve for 100 rounds.
# [2000]	training's l1: 0.0677244	valid_1's l1: 0.359251
# [4000]	training's l1: 0.0307712	valid_1's l1: 0.355609
# Early stopping, best iteration is:
# [4276]	training's l1: 0.0282643	valid_1's l1: 0.355373
# 1JHN Fold 0, logMAE: -1.0345877260545049
# Training until validation scores don't improve for 100 rounds.
# [2000]	training's l1: 0.0674444	valid_1's l1: 0.354805
# [4000]	training's l1: 0.0307684	valid_1's l1: 0.349886
# [6000]	training's l1: 0.018116	valid_1's l1: 0.348825
# Early stopping, best iteration is:
# [6683]	training's l1: 0.0156486	valid_1's l1: 0.348632
# 1JHN Fold 1, logMAE: -1.0537397073491823
# Training until validation scores don't improve for 100 rounds.
# [2000]	training's l1: 0.0681591	valid_1's l1: 0.353236
# [4000]	training's l1: 0.0308662	valid_1's l1: 0.348628
# Early stopping, best iteration is:
# [5579]	training's l1: 0.0198043	valid_1's l1: 0.347572
# 1JHN Fold 2, logMAE: -1.0567829320799658
# Training until validation scores don't improve for 100 rounds.
# [2000]	training's l1: 0.0681799	valid_1's l1: 0.347719
# [4000]	training's l1: 0.0309233	valid_1's l1: 0.342578
# [6000]	training's l1: 0.0180094	valid_1's l1: 0.341494
# Early stopping, best iteration is:
# [6351]	training's l1: 0.0166509	valid_1's l1: 0.341388
# 1JHN Fold 3, logMAE: -1.0747341649701796
# Training until validation scores don't improve for 100 rounds.
# [2000]	training's l1: 0.0681671	valid_1's l1: 0.353973
# [4000]	training's l1: 0.0313733	valid_1's l1: 0.34973
# Early stopping, best iteration is:
# [4966]	training's l1: 0.0237794	valid_1's l1: 0.349056
# 1JHN Fold 4, logMAE: -1.0525235771538148
# *** Training Model for 1JHC ***
# Index(['atom_2', 'atom_3', 'atom_4', 'atom_5', 'atom_6', 'atom_7', 'atom_8',
#        'atom_9', 'd_1_0', 'd_2_0', 'd_2_1', 'd_3_0', 'd_3_1', 'd_3_2', 'd_4_0',
#        'd_4_1', 'd_4_2', 'd_4_3', 'd_5_0', 'd_5_1', 'd_5_2', 'd_5_3', 'd_6_0',
#        'd_6_1', 'd_6_2', 'd_6_3', 'd_7_0', 'd_7_1', 'd_7_2', 'd_7_3', 'd_8_0',
#        'd_8_1', 'd_8_2', 'd_8_3', 'd_9_0', 'd_9_1', 'd_9_2', 'd_9_3',
#        'scalar_coupling_constant'],
#       dtype='object')
# Index(['atom_2', 'atom_3', 'atom_4', 'atom_5', 'atom_6', 'atom_7', 'atom_8',
#        'atom_9', 'd_1_0', 'd_2_0', 'd_2_1', 'd_3_0', 'd_3_1', 'd_3_2', 'd_4_0',
#        'd_4_1', 'd_4_2', 'd_4_3', 'd_5_0', 'd_5_1', 'd_5_2', 'd_5_3', 'd_6_0',
#        'd_6_1', 'd_6_2', 'd_6_3', 'd_7_0', 'd_7_1', 'd_7_2', 'd_7_3', 'd_8_0',
#        'd_8_1', 'd_8_2', 'd_8_3', 'd_9_0', 'd_9_1', 'd_9_2', 'd_9_3'],
#       dtype='object')
# Training until validation scores don't improve for 100 rounds.
# [2000]	training's l1: 0.542176	valid_1's l1: 0.767
# [4000]	training's l1: 0.385047	valid_1's l1: 0.698191
# [6000]	training's l1: 0.298627	valid_1's l1: 0.668213
# [8000]	training's l1: 0.241401	valid_1's l1: 0.650786
# [10000]	training's l1: 0.200542	valid_1's l1: 0.639917
# [12000]	training's l1: 0.169662	valid_1's l1: 0.632188
# [14000]	training's l1: 0.145821	valid_1's l1: 0.62686
# [16000]	training's l1: 0.126627	valid_1's l1: 0.622822
# [18000]	training's l1: 0.111085	valid_1's l1: 0.6197
# [20000]	training's l1: 0.0982459	valid_1's l1: 0.61722
# Did not meet early stopping. Best iteration is:
# [20000]	training's l1: 0.0982459	valid_1's l1: 0.61722
# 1JHC Fold 0, logMAE: -0.4825296840519346
# Training until validation scores don't improve for 100 rounds.
# [2000]	training's l1: 0
# Did not meet early stopping. Best iteration is:
# [20000]	training's l1: 0.00977423	valid_1's l1: 0.142314
# 2JHH Fold 4, logMAE: -1.9497208302254239
# *** Training Model for 2JHN ***
# Index(['atom_2', 'atom_3', 'atom_4', 'atom_5', 'atom_6', 'atom_7', 'atom_8',
#        'd_1_0', 'd_2_0', 'd_2_1', 'd_3_0', 'd_3_1', 'd_3_2', 'd_4_0', 'd_4_1',
#        'd_4_2', 'd_4_3', 'd_5_0', 'd_5_1', 'd_5_2', 'd_5_3', 'd_6_0', 'd_6_1',
#        'd_6_2', 'd_6_3', 'd_7_0', 'd_7_1', 'd_7_2', 'd_7_3', 'd_8_0', 'd_8_1',
#        'd_8_2', 'd_8_3', 'scalar_coupling_constant'],
#       dtype='object')
# Index(['atom_2', 'atom_3', 'atom_4', 'atom_5', 'atom_6', 'atom_7', 'atom_8',
#        'd_1_0', 'd_2_0', 'd_2_1', 'd_3_0', 'd_3_1', 'd_3_2', 'd_4_0', 'd_4_1',
#        'd_4_2', 'd_4_3', 'd_5_0', 'd_5_1', 'd_5_2', 'd_5_3', 'd_6_0', 'd_6_1',
#        'd_6_2', 'd_6_3', 'd_7_0', 'd_7_1', 'd_7_2', 'd_7_3', 'd_8_0', 'd_8_1',
#        'd_8_2', 'd_8_3'],
#       dtype='object')
# Training until validation scores don't improve for 100 rounds.
# [2000]	training's l1: 0.0446206	valid_1's l1: 0.134115
# [4000]	training's l1: 0.0238912	valid_1's l1: 0.128415
# [6000]	training's l1: 0.0153924	valid_1's l1: 0.126671
# [8000]	training's l1: 0.0110911	valid_1's l1: 0.125882
# [10000]	training's l1: 0.00863568	valid_1's l1: 0.125494
# [12000]	training's l1: 0.0071099	valid_1's l1: 0.125278
# [14000]	training's l1: 0.00607978	valid_1's l1: 0.12514
# [16000]	training's l1: 0.00533104	valid_1's l1: 0.125041
# [18000]	training's l1: 0.00476028	valid_1's l1: 0.124974
# Early stopping, best iteration is:
# [19384]	training's l1: 0.00443733	valid_1's l1: 0.124939
# 2JHN Fold 0, logMAE: -2.079931228612277
# Training until validation scores don't improve for 100 rounds.
# [2000]	training's l1: 0.045197	valid_1's l1: 0.132828
# [4000]	training's l1: 0.0240429	valid_1's l1: 0.127078
# [6000]	training's l1: 0.0155085	valid_1's l1: 0.125262
# [8000]	training's l1: 0.0111698	valid_1's l1: 0.124497
# [10000]	training's l1: 0.00869989	valid_1's l1: 0.124054
# [12000]	training's l1: 0.00716118	valid_1's l1: 0.12382
# [14000]	training's l1: 0.00611559	valid_1's l1: 0.123652
# [16000]	training's l1: 0.00536308	valid_1's l1: 0.123543
# [18000]	training's l1: 0.00478845	valid_1's l1: 0.123464
# [20000]	training's l1: 0.00433429	valid_1's l1: 0.123397
# Did not meet early stopping. Best iteration is:
# [20000]	training's l1: 0.00433429	valid_1's l1: 0.123397
# 2JHN Fold 1, logMAE: -2.0923471217276957
# Training until validation scores don't improve for 100 rounds.
# [2000]	training's l1: 0.0450965	valid_1's l1: 0.132369
# [4000]	training's l1: 0.0240513	valid_1's l1: 0.126763
# [6000]	training's l1: 0.0154742	valid_1's l1: 0.125077
# [8000]	training's l1: 0.0111634	valid_1's l1: 0.124307
# [10000]	training's l1: 0.00869842	valid_1's l1: 0.123893
# [12000]	training's l1: 0.00715164	valid_1's l1: 0.123672
# [14000]	training's l1: 0.00611251	valid_1's l1: 0.123526
# [16000]	training's l1: 0.00535921	valid_1's l1: 0.123417
# Early stopping, best iteration is:
# [16789]	training's l1: 0.00511832	valid_1's l1: 0.123383
# 2JHN Fold 2, logMAE: -2.092460830200605
# Training until validation scores don't improve for 100 rounds.
# [2000]	training's l1: 0.0451218	valid_1's l1: 0.134781
# [4000]	training's l1: 0.0240556	valid_1's l1: 0.128823
# [6000]	training's l1: 0.0154884	valid_1's l1: 0.126936
# [8000]	training's l1: 0.0111593	valid_1's l1: 0.126099
# [10000]	training's l1: 0.00869866	valid_1's l1: 0.125689
# [12000]	training's l1: 0.00715946	valid_1's l1: 0.12546
# [14000]	training's l1: 0.00611696	valid_1's l1: 0.125295
# [16000]	training's l1: 0.00536598	valid_1's l1: 0.125177
# [18000]	training's l1: 0.00479395	valid_1's l1: 0.125103
# [20000]	training's l1: 0.00433979	valid_1's l1: 0.125033
# Did not meet early stopping. Best iteration is:
# [20000]	training's l1: 0.00433979	valid_1's l1: 0.125033
# 2JHN Fold 3, logMAE: -2.0791737927552294
# Training until validation scores don't improve for 100 rounds.
# [2000]	training's l1: 0.0450323	valid_1's l1: 0.132884
# [4000]	training's l1: 0.0239918	valid_1's l1: 0.127257
# [6000]	training's l1: 0.0154717	valid_1's l1: 0.125488
# [8000]	training's l1: 0.0111328	valid_1's l1: 0.124724
# [10000]	training's l1: 0.0086698	valid_1's l1: 0.124317
# [12000]	training's l1: 0.0071259	valid_1's l1: 0.124069
# [14000]	training's l1: 0.0060872	valid_1's l1: 0.123926
# [16000]	training's l1: 0.00533198	valid_1's l1: 0.123826
# [18000]	training's l1: 0.00475856	valid_1's l1: 0.123753
# [20000]	training's l1: 0.00430565	valid_1's l1: 0.123696
# Did not meet early stopping. Best iteration is:
# [20000]	training's l1: 0.00430565	valid_1's l1: 0.123696
# 2JHN Fold 4, logMAE: -2.089931759654316
# *** Training Model for 2JHC ***
# Index(['atom_2', 'atom_3', 'atom_4', 'atom_5', 'atom_6', 'atom_7', 'atom_8',
#        'd_1_0', 'd_2_0', 'd_2_1', 'd_3_0', 'd_3_1', 'd_3_2', 'd_4_0', 'd_4_1',
#        'd_4_2', 'd_4_3', 'd_5_0', 'd_5_1', 'd_5_2', 'd_5_3', 'd_6_0', 'd_6_1',
#        'd_6_2', 'd_6_3', 'd_7_0', 'd_7_1', 'd_7_2', 'd_7_3', 'd_8_0', 'd_8_1',
#        'd_8_2', 'd_8_3', 'scalar_coupling_constant'],
#       dtype='object')
# Index(['atom_2', 'atom_3', 'atom_4', 'atom_5', 'atom_6', 'atom_7', 'atom_8',
#        'd_1_0', 'd_2_0', 'd_2_1', 'd_3_0', 'd_3_1', 'd_3_2', 'd_4_0', 'd_4_1',
#        'd_4_2', 'd_4_3', 'd_5_0', 'd_5_1', 'd_5_2', 'd_5_3', 'd_6_0', 'd_6_1',
#        'd_6_2', 'd_6_3', 'd_7_0', 'd_7_1', 'd_7_2', 'd_7_3', 'd_8_0', 'd_8_1',
#        'd_8_2', 'd_8_3'],
#       dtype='object')
# Training until validation scores don't improve for 100 rounds.
# [2000]	training's l1: 0.243102	valid_1's l1: 0.305506
# [4000]	training's l1: 0.182254	valid_1's l1: 0.270962
# [6000]	training's l1: 0.148383	valid_1's l1: 0.254989
# [8000]	training's l1: 0.125413	valid_1's l1: 0.245354
# [10000]	training's l1: 0.108381	valid_1's l1: 0.238833
# [12000]	training's l1: 0.0952323	valid_1's l1: 0.234184
# [14000]	training's l1: 0.0846314	valid_1's l1: 0.230767
# [16000]	training's l1: 0.0758464	valid_1's l1: 0.228053
# [18000]	training's l1: 0.0685729	valid_1's l1: 0.225927
# [20000]	training's l1: 0.0623244	valid_1's l1: 0.224195
# Did not meet early stopping. Best iteration is:
# [20000]	training's l1: 0.0623244	valid_1's l1: 0.224195
# 2JHC Fold 0, logMAE: -1.495239919988927
# Training until validation scores don't improve for 100 rounds.
# [2000]	training's l1: 0.24347	valid_1's l1: 0.305748
# [4000]	training's l1: 0.182534	valid_1's l1: 0.270688
# [6000]	training's l1: 0.148563	valid_1's l1: 0.254228
# [8000]	training's l1: 0.125667	valid_1's l1: 0.244608
# [10000]	training's l1: 0.10861	valid_1's l1: 0.238078
# [12000]	training's l1: 0.095319	valid_1's l1: 0.233472
# [14000]	training's l1: 0.0847248	valid_1's l1: 0.230044
# [16000]	training's l1: 0.0759648	valid_1's l1: 0.227276
# [18000]	training's l1: 0.0686103	valid_1's l1: 0.225063
# [20000]	training's l1: 0.0623667	valid_1's l1: 0.223321
# Did not meet early stopping. Best iteration is:
# [20000]	training's l1: 0.0623667	valid_1's l1: 0.223321
# 2JHC Fold 1, logMAE: -1.4991428772713256
# Training until validation scores don't improve for 100 rounds.
# [2000]	training's l1: 0.242927	valid_1's l1: 0.304507
# [4000]	training's l1: 0.182272	valid_1's l1: 0.269974
# [6000]	training's l1: 0.148483	valid_1's l1: 0.254091
# [8000]	training's l1: 0.125458	valid_1's l1: 0.244416
# [10000]	training's l1: 0.108469	valid_1's l1: 0.237983
# [12000]	training's l1: 0.0953262	valid_1's l1: 0.233358
# [14000]	training's l1: 0.0847466	valid_1's l1: 0.229965
# [16000]	training's l1: 0.0760383	valid_1's l1: 0.227249
# [18000]	training's l1: 0.0686719	valid_1's l1: 0.225132
# [20000]	training's l1: 0.0624541	valid_1's l1: 0.223401
# Did not meet early stopping. Best iteration is:
# [20000]	training's l1: 0.0624541	valid_1's l1: 0.223401
# 2JHC Fold 2, logMAE: -1.4987856831779767
# Training until validation scores don't improve for 100 rounds.
# [2000]	training's l1: 0
# Training until validation scores don't improve for 100 rounds.
# [2000]	training's l1: 0.116081	valid_1's l1: 0.169217
# [4000]	training's l1: 0.08014	valid_1's l1: 0.152532
# [6000]	training's l1: 0.0611013	valid_1's l1: 0.145441
# [8000]	training's l1: 0.0487735	valid_1's l1: 0.141612
# [10000]	training's l1: 0.0401054	valid_1's l1: 0.139111
# [12000]	training's l1: 0.0337198	valid_1's l1: 0.137434
# [14000]	training's l1: 0.0288208	valid_1's l1: 0.136278
# [16000]	training's l1: 0.0249575	valid_1's l1: 0.135408
# [18000]	training's l1: 0.0218665	valid_1's l1: 0.134743
# [20000]	training's l1: 0.0193547	valid_1's l1: 0.134239
# Did not meet early stopping. Best iteration is:
# [20000]	training's l1: 0.0193547	valid_1's l1: 0.134239
# 3JHH Fold 2, logMAE: -2.0081324018432967
# Training until validation scores don't improve for 100 rounds.
# [2000]	training's l1: 0.11584	valid_1's l1: 0.171011
# [4000]	training's l1: 0.0798472	valid_1's l1: 0.154303
# [6000]	training's l1: 0.0608315	valid_1's l1: 0.147239
# [8000]	training's l1: 0.0485922	valid_1's l1: 0.14338
# [10000]	training's l1: 0.0399971	valid_1's l1: 0.141009
# [12000]	training's l1: 0.0336054	valid_1's l1: 0.139384
# [14000]	training's l1: 0.0287089	valid_1's l1: 0.138225
# [16000]	training's l1: 0.0248671	valid_1's l1: 0.137385
# [18000]	training's l1: 0.0217634	valid_1's l1: 0.136743
# [20000]	training's l1: 0.0192557	valid_1's l1: 0.136228
# Did not meet early stopping. Best iteration is:
# [20000]	training's l1: 0.0192557	valid_1's l1: 0.136228
# 3JHH Fold 3, logMAE: -1.993424848742991
# Training until validation scores don't improve for 100 rounds.
# [2000]	training's l1: 0.115784	valid_1's l1: 0.169196
# [4000]	training's l1: 0.0799828	valid_1's l1: 0.152598
# [6000]	training's l1: 0.0610454	valid_1's l1: 0.14565
# [8000]	training's l1: 0.0487904	valid_1's l1: 0.141797
# [10000]	training's l1: 0.0401626	valid_1's l1: 0.139386
# [12000]	training's l1: 0.0337399	valid_1's l1: 0.137775
# [14000]	training's l1: 0.0288339	valid_1's l1: 0.136623
# [16000]	training's l1: 0.0249944	valid_1's l1: 0.135791
# [18000]	training's l1: 0.0219031	valid_1's l1: 0.135122
# [20000]	training's l1: 0.0193824	valid_1's l1: 0.134616
# Did not meet early stopping. Best iteration is:
# [20000]	training's l1: 0.0193824	valid_1's l1: 0.134616
# 3JHH Fold 4, logMAE: -2.0053292796368094
# *** Training Model for 3JHC ***
# Index(['atom_2', 'atom_3', 'atom_4', 'atom_5', 'atom_6', 'atom_7', 'atom_8',
#        'atom_9', 'd_1_0', 'd_2_0', 'd_2_1', 'd_3_0', 'd_3_1', 'd_3_2', 'd_4_0',
#        'd_4_1', 'd_4_2', 'd_4_3', 'd_5_0', 'd_5_1', 'd_5_2', 'd_5_3', 'd_6_0',
#        'd_6_1', 'd_6_2', 'd_6_3', 'd_7_0', 'd_7_1', 'd_7_2', 'd_7_3', 'd_8_0',
#        'd_8_1', 'd_8_2', 'd_8_3', 'd_9_0', 'd_9_1', 'd_9_2', 'd_9_3',
#        'scalar_coupling_constant'],
#       dtype='object')
# Index(['atom_2', 'atom_3', 'atom_4', 'atom_5', 'atom_6', 'atom_7', 'atom_8',
#        'atom_9', 'd_1_0', 'd_2_0', 'd_2_1', 'd_3_0', 'd_3_1', 'd_3_2', 'd_4_0',
#        'd_4_1', 'd_4_2', 'd_4_3', 'd_5_0', 'd_5_1', 'd_5_2', 'd_5_3', 'd_6_0',
#        'd_6_1', 'd_6_2', 'd_6_3', 'd_7_0', 'd_7_1', 'd_7_2', 'd_7_3', 'd_8_0',
#        'd_8_1', 'd_8_2', 'd_8_3', 'd_9_0', 'd_9_1', 'd_9_2', 'd_9_3'],
#       dtype='object')
# Training until validation scores don't improve for 100 rounds.
# [2000]	training's l1: 0.281695	valid_1's l1: 0.334479
# [4000]	training's l1: 0.217213	valid_1's l1: 0.295813
# [6000]	training's l1: 0.180779	valid_1's l1: 0.277676
# [8000]	training's l1: 0.15542	valid_1's l1: 0.266631
# [10000]	training's l1: 0.136333	valid_1's l1: 0.259044
# [12000]	training's l1: 0.121224	valid_1's l1: 0.253626
# [14000]	training's l1: 0.108875	valid_1's l1: 0.249459
# [16000]	training's l1: 0.0985019	valid_1's l1: 0.246111
# [18000]	training's l1: 0.0896882	valid_1's l1: 0.243453
# [20000]	training's l1: 0.0821422	valid_1's l1: 0.241269
# Did not meet early stopping. Best iteration is:
# [20000]	training's l1: 0.0821422	valid_1's l1: 0.241269
# 3JHC Fold 0, logMAE: -1.4218439027948566
# Training until validation scores don't improve for 100 rounds.
# [2000]	training's l1: 0.281698	valid_1's l1: 0.335282
# [4000]	training's l1: 0.217174	valid_1's l1: 0.296474
# [6000]	training's l1: 0.180602	valid_1's l1: 0.278125
# [8000]	training's l1: 0.155382	valid_1's l1: 0.267089
# [10000]	training's l1: 0.136319	valid_1's l1: 0.259542
# [12000]	training's l1: 0.1212	valid_1's l1: 0.25413
# [14000]	training's l1: 0.108744	valid_1's l1: 0.249931
# [16000]	training's l1: 0.098324	valid_1's l1: 0.246606
# [18000]	training's l1: 0.0895381	valid_1's l1: 0.243949
# [20000]	training's l1: 0.0818668	valid_1's l1: 0.241729
# Did not meet early stopping. Best iteration is:
# [20000]	training's l1: 0.0818668	valid_1's l1: 0.241729
# 3JHC Fold 1, logMAE: -1.4199373385488232
# Training until validation scores don't improve for 100 rounds.
# [2000]	training's l1: 0.282728	valid_1's l1: 0.335649
# [4000]	training's l1: 0.218233	valid_1's l1: 0.296756
# [6000]	training's l1: 0.181361	valid_1's l1: 0.278184
# [8000]	training's l1: 0.155863	valid_1's l1: 0.266909
# [10000]	training's l1: 0.136724	valid_1's l1: 0.259302
# [12000]	training's l1: 0.121587	valid_1's l1: 0.253903
# [14000]	training's l1: 0.109168	valid_1's l1: 0.249761
# [16000]	training's l1: 0.0987505	valid_1's l1: 0.246462
# [18000]	training's l1: 0.0898688	valid_1's l1: 0.243797
# [20000]	training's l1: 0.0822712	valid_1's l1: 0.241614
# Did not meet early stopping. Best iteration is:
# [20000]	training's l1: 0.0822712	valid_1's l1: 0.241614
# 3JHC Fold 2, logMAE: -1.420412161072714
# Training until validation scores don't improve for 100 rounds.
# [2000]	training's l1: 0.281781	valid_1's l1: 0.336192
# [4000]	training's l1: 0.217447	valid_1's l1: 0.297382
# [6000]	training's l1: 0.180731	valid_1's l1: 0.27907
# [8000]	training's l1: 0.155234	valid_1's l1: 0.267968
# [10000]	training's l1: 0.136245	valid_1's l1: 0.260491
# [12000]	training's l1: 0.121053	valid_1's l1: 0.254993
# [14000]	training's l1: 0.108672	valid_1's l1: 0.250828
# [16000]	training's l1: 0.0983438	valid_1's l1: 0.247559
# [18000]	training's l1: 0.0895886	valid_1's l1: 0.244911
# [20000]	training's l1: 0.0819732	valid_1's l1: 0.24271
# Did not meet early stopping. Best iteration is:
# [20000]	training's l1: 0.0819732	valid_1's l1: 0.24271
# 3JHC Fold 3, logMAE: -1.415888522697474
# Training until validation scores don't improve for 100 rounds.
# [2000]	training's l1: 0.281822	valid_1's l1: 0.33577
# [4000]	training's l1: 0.217285	valid_1's l1: 0.296711
# [6000]	training's l1: 0.180634	valid_1's l1: 0.278492
# [8000]	training's l1: 0.155259	valid_1's l1: 0.267452
# [10000]	training's l1: 0.136179	valid_1's l1: 0.259929
# [12000]	training's l1: 0.121089	valid_1's l1: 0.254528
# [14000]	training's l1: 0.108669	valid_1's l1: 0.250334
# [16000]	training's l1: 0.0983479	valid_1's l1: 0.246964
# [18000]	training's l1: 0.089508	valid_1's l1: 0.244328
# [20000]	training's l1: 0.0818901	valid_1's l1: 0.242154
# Did not meet early stopping. Best iteration is:
# [20000]	training's l1: 0.0818901	valid_1's l1: 0.242154
# 3JHC Fold 4, logMAE: -1.4181815163559974

# %%
pd.DataFrame({'type': list(cv_scores.keys()), 'cv_score': list(cv_scores.values())})

# %%
np.mean(list(cv_scores.values()))
# -1.490242925007926

# %%
submission[submission['scalar_coupling_constant'] == 0].shape

# %%
submission.to_csv('lgb_20k_0.1lr.csv')
